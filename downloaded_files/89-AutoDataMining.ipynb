# %% [markdown]
# # Extracting Title of the Table

# %%
import xml.etree.ElementTree as ET
namespaces = {'ce': 'http://www.elsevier.com/xml/common/dtd'}
filepath = "C:/Users/shulo/DataExtractor/DataExtractor/notebook/Demos/testing_download_articles/write_test_els_paper6.xml"
def header(filepath, target_tabl_id):    
    lst = []
    tree = ET.parse(filepath) #read in the XML
    for tags in tree.iter('{http://www.elsevier.com/xml/common/dtd}table'):
        tabl_id = tags.find('ce:caption', namespaces).attrib['id']
        if tabl_id == target_tabl_id:#choose the row to pull from
            for var in tags.iter('{http://www.elsevier.com/xml/common/dtd}caption'):
                name = var.find('ce:simple-para', namespaces).text
                lst.append(name)
    return lst
output = header(filepath, "cap0070")
print(output)
# Out:
# ['Summary of photophysical and thermal properties of Py(5,9)BTPE and Py(5,9)BTriPE.']

# %% [markdown]
# # The MEAT

# %%
import pandas as pd
import numpy as np
import xml.etree.ElementTree as ET

filepath = "C:/Users/shulo/DataExtractor/DataExtractor/notebook/Demos/testing_download_articles/write_test_els_paper6.xml"
tree = ET.parse(filepath)
root = ET.tostring(tree.getroot())

content_list = []
total_list = ['material_names']
sub_header = []
sub_header.append('')
all_tables = []

table_lists = tree.iter('{http://www.elsevier.com/xml/common/dtd}table')
for table in table_lists:
    lst = table.iter('{http://www.elsevier.com/xml/common/cals/dtd}thead')
    for tags in lst:
        rows = tags.findall('{http://www.elsevier.com/xml/common/cals/dtd}row')
        entry_list = rows[0].findall('{http://www.elsevier.com/xml/common/dtd}entry')
        for every_entry in entry_list:
            header = every_entry.text
            for x in every_entry:
                subscript = x.text
                units = x.tail
                total = header + subscript + units
                #print(total)
                total_list.append(total)
                if 'role' in every_entry.attrib.values():
                    if every_entry.attrib['role'] == 'colgroup':
                        total_list.append('')
        if len(rows) == 2:
            entry_list = rows[1].findall('{http://www.elsevier.com/xml/common/dtd}entry')
            for more_entry in entry_list: 
                header2 = more_entry.text
                subscript2 = ''
                units2 = ''
                for more_content in more_entry: 
                    if more_content == ('{http://www.elsevier.com/xml/common/dtd}inf'):
                        more_information = content.findall('{http://www.elsevier.com/xml/common/dtd}inf')
                for y in more_entry:
                    subscript2 = y.text
                    units2 = y.tail
                total2 = header2 + subscript2 + units2
                sub_header.append(total2)
                #print(total2)
    content_list.append(sub_header)
    lst2 = tree.iter('{http://www.elsevier.com/xml/common/cals/dtd}tbody')
    for data in lst2:
        rows = data.findall('{http://www.elsevier.com/xml/common/cals/dtd}row')
        for row in rows: 
            entry_list = row.findall('{http://www.elsevier.com/xml/common/dtd}entry')
            row_data = []
            for entry in entry_list:
                content = entry.text
                row_data.append(content)
            content_list.append(row_data)
    rows = content_list
    df = pd.DataFrame(rows, columns = total_list)
    print(df)
    df.to_csv('Table.csv',encoding='utf-8')
    content_list = []
    total_list = []
    sub_header = []
    sub_header.append('')
    all_tables.append(df)
# Out:
#                    material_names  \
# 0
# 1                     Py(5,9)BTPE
# 2                   Py(5,9)BTriPE
# 3                               A
# 4                               B
# 5   \n
# 6   \n
# 7   \n
# 8   \n
# 9   \n
# 10  \n
# 11  \n
# 12  \n
#
#                                             λabs [nm]  \
# 0   soln\n                              \n        ...
# 1                                                 371
# 2                                                 381
# 3                                                 488
# 4                                                 456
# 5                                                 3.2
# 6                                                 4.6
# 7                                                 4.9
# 8                                                 4.2
# 9                                                 4.3
# 10                                                3.6
# 11                                                4.0
# ...

# %% [markdown]
# # Finding URL assoicated with each tags

# %%
import xml.etree.ElementTree as ET
namespaces = {'ce': 'http://www.elsevier.com/xml/common/dtd'}
filepath = "C:/Users/shulo/DataExtractor/DataExtractor/notebook/Demos/testing_download_articles/write_test_els_paper6.xml"
tree = ET.parse(filepath)
root = ET.tostring(tree.getroot())
lst = list(tree.iter())
print(lst)
for tags in lst: 
    row = tags.find('{http://www.elsevier.com/xml/svapi/article/dtd}row').text
    entry = tags.find('{http://www.elsevier.com/xml/svapi/article/dtd}entry').text
# Out:
# [<Element '{http://www.elsevier.com/xml/svapi/article/dtd}full-text-retrieval-response' at 0x000001EADD636F98>, <Element '{http://www.elsevier.com/xml/svapi/article/dtd}coredata' at 0x000001EADD65BD68>, <Element '{http://prismstandard.org/namespaces/basic/2.0/}url' at 0x000001EADD65BDB8>, <Element '{http://purl.org/dc/elements/1.1/}identifier' at 0x000001EADD65BE58>, <Element '{http://www.elsevier.com/xml/svapi/article/dtd}eid' at 0x000001EADD65BEA8>, <Element '{http://prismstandard.org/namespaces/basic/2.0/}doi' at 0x000001EADD65BF48>, <Element '{http://www.elsevier.com/xml/svapi/article/dtd}pii' at 0x000001EADD65D048>, <Element '{http://purl.org/dc/elements/1.1/}title' at 0x000001EADD65D138>, <Element '{http://prismstandard.org/namespaces/basic/2.0/}publicationName' at 0x000001EADD65D188>, <Element '{http://prismstandard.org/namespaces/basic/2.0/}aggregationType' at 0x000001EADD65D228>, <Element '{http://prismstandard.org/namespaces/basic/2.0/}issn' at 0x000001EADD65D278>, <Element
# ...

# %%
import pandas as pd
import numpy as np
import xml.etree.ElementTree as ET
filepath = "C:/Users/shulo/DataExtractor/DataExtractor/notebook/Demos/testing_download_articles/write_test_els_paper6.xml"
tree = ET.parse(filepath)
root = ET.tostring(tree.getroot())
lst = tree.iter('{http://www.elsevier.com/xml/common/cals/dtd}thead')
content_list = []
total_list = []
for tags in lst:
    col = tags.find('{http://www.elsevier.com/xml/common/cals/dtd}row')
    entry_list = col.findall('{http://www.elsevier.com/xml/common/dtd}entry') 
    for entry in entry_list:
        header = entry.text
        for content in entry:
            if content == ('{http://www.elsevier.com/xml/common/dtd}inf'):
                information = content.findall('{http://www.elsevier.com/xml/common/dtd}inf')
        for x in entry:
            subscript = x.text
            units = x.tail
            total = header + subscript + units
            total_list.append(total)
            print(total)
print(total_list)
# Out:
# λabs [nm]
# λem [nm]
# ΦF
#
# Φ
#                                [%]
# τ
#                                [ns]
# Tg/T
# Tm/T
# Td [°C]
# Eg
#
# E
#                                [eV]
# LUMO/HOMO
#                                [eV]
# λEL
#
# λ
#                                [nm]
# Lmax
#
# L
#                                [cd m
# L−2]
# CEmax
#
# CE
#                                [cd A
# CE−1]
# PEmax
#
# PE
#                                [lm W
# PE−1]
# EQE
#                                [%]
# CIE
#                                (x,y)
# Von
#
# V
#                                [V]
#
#                            V
#
#
#                            on (v)
#
#                            L
#
#
#                            max (cd m
#
#                            −2)
# ηC,max (cd A
# η−1)
# ηP,max (lm W
# η−1)
# λEL (nm)
# ...

# %% [markdown]
# # The MEAT p2

# %%
import pandas as pd
import numpy as np
import xml.etree.ElementTree as ET
filepath = "C:/Users/shulo/DataExtractor/DataExtractor/notebook/Demos/testing_download_articles/write_test_els_paper6.xml"
tree = ET.parse(filepath)
root = ET.tostring(tree.getroot())
lst = tree.iter('{http://www.elsevier.com/xml/common/cals/dtd}thead')
content_list = []
total_list = ['material_names']
sub_header = []
sub_header.append('')
for tags in lst:
    rows = tags.findall('{http://www.elsevier.com/xml/common/cals/dtd}row')
    entry_list = rows[0].findall('{http://www.elsevier.com/xml/common/dtd}entry')
    for every_entry in entry_list:
        header = every_entry.text
        for content in every_entry:
            if content == ('{http://www.elsevier.com/xml/common/dtd}inf'):
                information = content.findall('{http://www.elsevier.com/xml/common/dtd}inf')
        for x in every_entry:
            subscript = x.text
            units = x.tail
            total = header + subscript + units
            #print(total)
#Check how many cols does the entry takes, if it takes more than 1.
#For every entry above 1, in addition to append the entry, also append a empty quotes ('')
            total_list.append(total)
            if 'role' in every_entry.attrib.values():
                if every_entry.attrib['role'] == 'colgroup':
                    total_list.append('')
    if len(rows) == 2:
        entry_list = rows[1].findall('{http://www.elsevier.com/xml/common/dtd}entry')
        for more_entry in entry_list: 
            header2 = more_entry.text
            subscript2 = ''
            units2 = ''
            for more_content in more_entry: 
                if more_content == ('{http://www.elsevier.com/xml/common/dtd}inf'):
                    more_information = content.findall('{http://www.elsevier.com/xml/common/dtd}inf')
            for y in more_entry:
                subscript2 = y.text
                units2 = y.tail
            total2 = header2 + subscript2 + units2
            sub_header.append(total2)
            #print(total2)
    break
content_list.append(sub_header)
lst2 = tree.iter('{http://www.elsevier.com/xml/common/cals/dtd}tbody')
for data in lst2:
    rows = data.findall('{http://www.elsevier.com/xml/common/cals/dtd}row')#Add another for loop here to find all of the row tags
    for row in rows: 
        entry_list = row.findall('{http://www.elsevier.com/xml/common/dtd}entry')
        row_data = []
        for entry in entry_list:
            content = entry.text
            row_data.append(content)
        content_list.append(row_data)
    break
rows = content_list
df = pd.DataFrame(rows, columns = total_list)
print(df)
df.to_csv('Table1.csv', encoding='utf-8')
# Out:
#   material_names                                          λabs [nm]  \
# 0                 soln\n                              \n        ...
# 1    Py(5,9)BTPE                                                371
# 2  Py(5,9)BTriPE                                                381
#
#                                             λem [nm]  \
# 0  film\n                              \n        ...
# 1                                                376
# 2                                                382
#
#                      ΦF\n                             \
# 0  soln\n                              \n        ...
# 1                                                419
# 2                                                411
#
#                Φ\n                               [%]  \
# 0  film\n                              \n        ...
# 1                                                491
# 2                                                453
#
# ...

# %%
import pandas as pd
import numpy as np
import xml.etree.ElementTree as ET
filepath = "C:/Users/shulo/DataExtractor/DataExtractor/notebook/Demos/testing_download_articles/write_test_els_paper6.xml"
tree = ET.parse(filepath)
root = ET.tostring(tree.getroot())
lst = tree.iter('{http://www.elsevier.com/xml/common/cals/dtd}thead')
content_list = []
total_list = ['material_names']
sub_header = []
sub_header.append('')
for tags in lst:
    rows = tags.findall('{http://www.elsevier.com/xml/common/cals/dtd}row')
    entry_list = rows[0].findall('{http://www.elsevier.com/xml/common/dtd}entry')
    for every_entry in entry_list:
        header = every_entry.text
        for content in every_entry:
            if content == ('{http://www.elsevier.com/xml/common/dtd}inf'):
                information = content.findall('{http://www.elsevier.com/xml/common/dtd}inf')
        for x in every_entry:
            subscript = x.text
            units = x.tail
            total = header + subscript + units
            #print(total)
#Check how many cols does the entry takes, if it takes more than 1.
#For every entry above 1, in addition to append the entry, also append a empty quotes ('')
            total_list.append(total)
            if 'role' in every_entry.attrib.values():
                if every_entry.attrib['role'] == 'colgroup':
                    total_list.append('')
    if len(rows) == 2:
        entry_list = rows[1].findall('{http://www.elsevier.com/xml/common/dtd}entry')
        for more_entry in entry_list: 
            header2 = more_entry.text
            subscript2 = ''
            units2 = ''
            for more_content in more_entry: 
                if more_content == ('{http://www.elsevier.com/xml/common/dtd}inf'):
                    more_information = content.findall('{http://www.elsevier.com/xml/common/dtd}inf')
            for y in more_entry:
                subscript2 = y.text
                units2 = y.tail
            total2 = header2 + subscript2 + units2
            sub_header.append(total2)
            #print(total2)
    break
content_list.append(sub_header)
lst2 = tree.iter('{http://www.elsevier.com/xml/common/cals/dtd}tbody')
for data in lst2:
    rows = data.findall('{http://www.elsevier.com/xml/common/cals/dtd}row')#Add another for loop here to find all of the row tags
    for row in rows: 
        entry_list = row.findall('{http://www.elsevier.com/xml/common/dtd}entry')
        row_data = []
        for entry in entry_list:
            content = entry.text
            row_data.append(content)
        content_list.append(row_data)
    break
rows = content_list
df = pd.DataFrame(rows, columns = total_list)
print(df)
df.to_csv('Table1.csv', encoding='utf-8')
