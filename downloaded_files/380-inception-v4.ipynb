# %%
import os

os.environ['KERAS_BACKEND'] = 'tensorflow'
os.environ['CUDA_HOME'] = '/usr/local/cuda-7.5'

# %%
import numpy as np
import tensorflow as tf
from keras.datasets import cifar10
from keras.layers import Dense, Dropout, Activation, Flatten, Lambda, BatchNormalization
from keras.layers import Convolution2D, MaxPooling2D, AveragePooling2D ,concatenate
from keras.engine import Input, Model 
from keras.optimizers import SGD
from keras.callbacks import Callback, LearningRateScheduler, ModelCheckpoint, EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import np_utils
import keras.backend as K
import json
import time
# Out:
# Using TensorFlow backend.

# %%
nb_classes = 10

# the data, shuffled and split between train and test sets
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# reorder dimensions for tensorflowr
x_train = np.transpose(x_train.astype('float32') / 255., (0, 1, 2, 3))
x_test = np.transpose(x_test.astype('float32') / 255., (0, 1, 2, 3))
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %% [markdown]
# # inception v4
#
# http://arxiv.org/pdf/1602.07261v1.pdf

# %%
# we reduce # filters by factor of 8 compared to original inception-v4
nb_filters_reduction_factor = 8

def inception_v4_stem(x):
    # in original inception-v4, conv stride is 2
    x = Convolution2D(32//nb_filters_reduction_factor, 3, 3, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='valid', dim_ordering='tf')(x)
    x = Convolution2D(32//nb_filters_reduction_factor, 3, 3, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='valid', dim_ordering='tf')(x)
    x = Convolution2D(64//nb_filters_reduction_factor, 3, 3, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='same', dim_ordering='tf')(x)
    
    # in original inception-v4, stride is 2
    a = MaxPooling2D((3, 3), strides=(1, 1), border_mode='valid', dim_ordering='tf')(x)
    # in original inception-v4, conv stride is 2
    b = Convolution2D(96//nb_filters_reduction_factor, 3, 3, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='valid', dim_ordering='tf')(x)
    #x = merge([a, b], mode='concat', concat_axis=-1)
    x=concatenate([a,b],axis=-1)
    #x=keras.layers.Concatenate([a,b],axis=1)
    a = Convolution2D(64//nb_filters_reduction_factor, 1, 1, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='same', dim_ordering='tf')(x)
    a = Convolution2D(96//nb_filters_reduction_factor, 3, 3, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='valid', dim_ordering='tf')(a)
    b = Convolution2D(64//nb_filters_reduction_factor, 1, 1, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='same', dim_ordering='tf')(x)
    b = Convolution2D(64//nb_filters_reduction_factor, 7, 1, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='same', dim_ordering='tf')(b)
    b = Convolution2D(64//nb_filters_reduction_factor, 1, 7, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='same', dim_ordering='tf')(b)
    b = Convolution2D(96//nb_filters_reduction_factor, 3, 3, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='valid', dim_ordering='tf')(b)
    #x = merge([a, b], mode='concat', concat_axis=-1)
    x=concatenate([a,b],axis=-1)
    # in original inception-v4, conv stride should be 2
    a = Convolution2D(192//nb_filters_reduction_factor, 3, 3, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='valid', dim_ordering='tf')(x)
    # in original inception-v4, stride is 2
    b = MaxPooling2D((3, 3), strides=(1, 1), border_mode='valid', dim_ordering='tf')(x)
    #x = merge([a, b], mode='concat', concat_axis=-1)
    x=concatenate([a,b],axis=-1)
    return x


def inception_v4_A(x):
    a = AveragePooling2D((3, 3), strides=(1, 1), border_mode='same', dim_ordering='tf')(x)
    a = Convolution2D(96//nb_filters_reduction_factor, 1, 1, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='same', dim_ordering='tf')(a)
    
    b = Convolution2D(96//nb_filters_reduction_factor, 1, 1, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='same', dim_ordering='tf')(x)
    
    c = Convolution2D(64//nb_filters_reduction_factor, 1, 1, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='same', dim_ordering='tf')(x)
    c = Convolution2D(96//nb_filters_reduction_factor, 3, 3, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='same', dim_ordering='tf')(c)
    
    d = Convolution2D(64//nb_filters_reduction_factor, 1, 1, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='same', dim_ordering='tf')(x)
    d = Convolution2D(96//nb_filters_reduction_factor, 3, 3, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='same', dim_ordering='tf')(d)
    d = Convolution2D(96//nb_filters_reduction_factor, 3, 3, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='same', dim_ordering='tf')(d)
    
    #x = merge([a, b, c, d], mode='concat', concat_axis=-1)
    x=concatenate([a,b,c,d],axis=-1)
    return x


def inception_v4_reduction_A(x):
    a = MaxPooling2D((3, 3), strides=(2, 2), border_mode='valid', dim_ordering='tf')(x)
    b = Convolution2D(384//nb_filters_reduction_factor, 3, 3, subsample=(2, 2), activation='relu',
                      init='he_normal', border_mode='valid', dim_ordering='tf')(x)
    c = Convolution2D(192//nb_filters_reduction_factor, 1, 1, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='same', dim_ordering='tf')(x)
    c = Convolution2D(224//nb_filters_reduction_factor, 3, 3, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='same', dim_ordering='tf')(c)
    c = Convolution2D(256//nb_filters_reduction_factor, 3, 3, subsample=(2, 2), activation='relu',
                      init='he_normal', border_mode='valid', dim_ordering='tf')(c)
    
    #x = merge([a, b, c], mode='concat', concat_axis=-1)
    x=concatenate([a,b,c],axis=-1)
    return x
    

def inception_v4_B(x):
    a = AveragePooling2D((3, 3), strides=(1, 1), border_mode='same', dim_ordering='tf')(x)
    a = Convolution2D(128//nb_filters_reduction_factor, 1, 1, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='same', dim_ordering='tf')(a)
    
    b = Convolution2D(384//nb_filters_reduction_factor, 1, 1, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='same', dim_ordering='tf')(x)
    
    c = Convolution2D(192//nb_filters_reduction_factor, 1, 1, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='same', dim_ordering='tf')(x)
    c = Convolution2D(224//nb_filters_reduction_factor, 1, 7, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='same', dim_ordering='tf')(c)
    c = Convolution2D(256//nb_filters_reduction_factor, 1, 7, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='same', dim_ordering='tf')(c)
    
    d = Convolution2D(192//nb_filters_reduction_factor, 1, 1, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='same', dim_ordering='tf')(x)
    d = Convolution2D(192//nb_filters_reduction_factor, 1, 7, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='same', dim_ordering='tf')(d)
    d = Convolution2D(224//nb_filters_reduction_factor, 7, 1, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='same', dim_ordering='tf')(d)
    d = Convolution2D(224//nb_filters_reduction_factor, 1, 7, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='same', dim_ordering='tf')(d)
    d = Convolution2D(256//nb_filters_reduction_factor, 7, 1, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='same', dim_ordering='tf')(d)
    
    #x = merge([a, b, c, d], mode='concat', concat_axis=-1)
    x=concatenate([a,b,c,d],axis=-1)
    return x


def inception_v4_reduction_B(x):
    a = MaxPooling2D((3, 3), strides=(2, 2), border_mode='valid', dim_ordering='tf')(x)
    b = Convolution2D(192//nb_filters_reduction_factor, 1, 1, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='same', dim_ordering='tf')(x)
    b = Convolution2D(192//nb_filters_reduction_factor, 3, 3, subsample=(2, 2), activation='relu',
                      init='he_normal', border_mode='valid', dim_ordering='tf')(b)
    c = Convolution2D(256//nb_filters_reduction_factor, 1, 1, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='same', dim_ordering='tf')(x)
    c = Convolution2D(256//nb_filters_reduction_factor, 1, 7, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='same', dim_ordering='tf')(c)
    c = Convolution2D(320//nb_filters_reduction_factor, 7, 1, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='same', dim_ordering='tf')(c)
    c = Convolution2D(320//nb_filters_reduction_factor, 3, 3, subsample=(2, 2), activation='relu',
                      init='he_normal', border_mode='valid', dim_ordering='tf')(c)
    
    #x = merge([a, b, c], mode='concat', concat_axis=-1)
    x=concatenate([a,b,c],axis=-1)
    return x


def inception_v4_C(x):
    a = AveragePooling2D((3, 3), strides=(1, 1), border_mode='same', dim_ordering='tf')(x)
    a = Convolution2D(256//nb_filters_reduction_factor, 1, 1, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='same', dim_ordering='tf')(a)
    
    b = Convolution2D(256//nb_filters_reduction_factor, 1, 1, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='same', dim_ordering='tf')(x)
    
    c = Convolution2D(384//nb_filters_reduction_factor, 1, 1, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='same', dim_ordering='tf')(x)
    c1 = Convolution2D(256//nb_filters_reduction_factor, 1, 3, subsample=(1, 1), activation='relu',
                       init='he_normal', border_mode='same', dim_ordering='tf')(c)
    c2 = Convolution2D(256//nb_filters_reduction_factor, 3, 1, subsample=(1, 1), activation='relu',
                       init='he_normal', border_mode='same', dim_ordering='tf')(c)
    
    d = Convolution2D(384//nb_filters_reduction_factor, 1, 1, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='same', dim_ordering='tf')(x)
    d = Convolution2D(448//nb_filters_reduction_factor, 1, 3, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='same', dim_ordering='tf')(d)
    d = Convolution2D(512//nb_filters_reduction_factor, 3, 1, subsample=(1, 1), activation='relu',
                      init='he_normal', border_mode='same', dim_ordering='tf')(d)
    d1 = Convolution2D(256//nb_filters_reduction_factor, 3, 1, subsample=(1, 1), activation='relu',
                       init='he_normal', border_mode='same', dim_ordering='tf')(d)
    d2 = Convolution2D(256//nb_filters_reduction_factor, 1, 3, subsample=(1, 1), activation='relu',
                       init='he_normal', border_mode='same', dim_ordering='tf')(d)
    
    #x = merge([a, b, c1, c2, d1, d2], mode='concat', concat_axis=-1)
    x=concatenate([a,b,c1, c2, d1, d2],axis=-1)
    return x

# %%
# %%time

img_rows, img_cols = 32, 32
img_channels = 3

# in original inception-v4, these are 4, 7, 3, respectively
num_A_blocks = 1
num_B_blocks = 1
num_C_blocks = 1

inputs = Input(shape=(img_rows, img_cols, img_channels))

x = inception_v4_stem(inputs)
for i in range(num_A_blocks):
    x = inception_v4_A(x)
x = inception_v4_reduction_A(x)
for i in range(num_B_blocks):
    x = inception_v4_B(x)
x = inception_v4_reduction_B(x)
for i in range(num_C_blocks):
    x = inception_v4_C(x)

x = AveragePooling2D(pool_size=(4, 4), strides=(1, 1), border_mode='valid', dim_ordering='tf')(x)
x = Dropout(0.5)(x)
x = Flatten()(x)

predictions = Dense(nb_classes, activation='softmax')(x)

model = Model(input=inputs, output=predictions)
# Out:
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(4, (3, 3), activation="relu", strides=(1, 1), padding="valid", data_format="channels_last", kernel_initializer="he_normal")`
#   import sys
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(4, (3, 3), activation="relu", strides=(1, 1), padding="valid", data_format="channels_last", kernel_initializer="he_normal")`
#   if __name__ == '__main__':
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(8, (3, 3), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: UserWarning: Update your `MaxPooling2D` call to the Keras 2 API: `MaxPooling2D((3, 3), strides=(1, 1), padding="valid", data_format="channels_last")`
#
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(12, (3, 3), activation="relu", strides=(1, 1), padding="valid", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(8, (1, 1), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(12, (3, 3), activation="relu", strides=(1, 1), padding="valid", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(8, (1, 1), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:28: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(8, (7, 1), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(8, (1, 7), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(12, (3, 3), activation="relu", strides=(1, 1), padding="valid", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(24, (3, 3), activation="relu", strides=(1, 1), padding="valid", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:39: UserWarning: Update your `MaxPooling2D` call to the Keras 2 API: `MaxPooling2D((3, 3), strides=(1, 1), padding="valid", data_format="channels_last")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: UserWarning: Update your `AveragePooling2D` call to the Keras 2 API: `AveragePooling2D((3, 3), strides=(1, 1), padding="same", data_format="channels_last")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:48: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(12, (1, 1), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:51: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(12, (1, 1), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:54: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(8, (1, 1), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:56: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(12, (3, 3), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(8, (1, 1), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(12, (3, 3), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:63: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(12, (3, 3), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:71: UserWarning: Update your `MaxPooling2D` call to the Keras 2 API: `MaxPooling2D((3, 3), strides=(2, 2), padding="valid", data_format="channels_last")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:73: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 3), activation="relu", strides=(2, 2), padding="valid", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:75: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(24, (1, 1), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:77: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(28, (3, 3), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:79: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), activation="relu", strides=(2, 2), padding="valid", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:87: UserWarning: Update your `AveragePooling2D` call to the Keras 2 API: `AveragePooling2D((3, 3), strides=(1, 1), padding="same", data_format="channels_last")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:89: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(16, (1, 1), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:92: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (1, 1), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:95: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(24, (1, 1), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:97: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(28, (1, 7), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:99: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 7), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:102: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(24, (1, 1), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:104: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(24, (1, 7), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(28, (7, 1), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(28, (1, 7), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:110: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (7, 1), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:118: UserWarning: Update your `MaxPooling2D` call to the Keras 2 API: `MaxPooling2D((3, 3), strides=(2, 2), padding="valid", data_format="channels_last")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:120: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(24, (1, 1), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:122: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(24, (3, 3), activation="relu", strides=(2, 2), padding="valid", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:124: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:126: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 7), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:128: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(40, (7, 1), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:130: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(40, (3, 3), activation="relu", strides=(2, 2), padding="valid", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:138: UserWarning: Update your `AveragePooling2D` call to the Keras 2 API: `AveragePooling2D((3, 3), strides=(1, 1), padding="same", data_format="channels_last")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:140: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:143: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:146: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (1, 1), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:148: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 3), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:150: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 1), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:153: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (1, 1), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:155: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(56, (1, 3), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:157: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 1), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:159: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 1), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:161: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 3), activation="relu", strides=(1, 1), padding="same", data_format="channels_last", kernel_initializer="he_normal")`
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: UserWarning: Update your `AveragePooling2D` call to the Keras 2 API: `AveragePooling2D(pool_size=(4, 4), strides=(1, 1), padding="valid", data_format="channels_last")`
# Wall time: 4.04 s
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:28: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 30, 30, 4)    112         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 28, 28, 4)    148         conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 28, 28, 8)    296         conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 26, 26, 8)    0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 26, 26, 12)   876         conv2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 26, 26, 20)   0           max_pooling2d_1[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 26, 26, 8)    168         concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 26, 26, 8)    456         conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 26, 26, 8)    168         concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 26, 26, 8)    456         conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 24, 24, 12)   876         conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 24, 24, 12)   876         conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 24, 24, 24)   0           conv2d_6[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 22, 22, 24)   5208        concatenate_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 22, 22, 24)   0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 22, 22, 48)   0           conv2d_11[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 22, 22, 8)    392         concatenate_3[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 22, 22, 48)   0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 22, 22, 8)    392         concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 22, 22, 12)   876         conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 22, 22, 12)   588         average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 22, 22, 12)   588         concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 22, 22, 12)   876         conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 22, 22, 12)   1308        conv2d_17[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 22, 22, 48)   0           conv2d_12[0][0]
#                                                                  conv2d_13[0][0]
#                                                                  conv2d_15[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 22, 22, 24)   1176        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 22, 22, 28)   6076        conv2d_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 10, 10, 48)   0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 10, 10, 48)   20784       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 10, 10, 32)   8096        conv2d_21[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 10, 10, 128)  0           max_pooling2d_3[0][0]
#                                                                  conv2d_19[0][0]
#                                                                  conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 10, 10, 24)   3096        concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 10, 10, 24)   4056        conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 10, 10, 24)   3096        concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 10, 10, 28)   4732        conv2d_29[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 10, 10, 128)  0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 10, 10, 28)   4732        conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 10, 10, 28)   5516        conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 10, 10, 16)   2064        average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 10, 10, 48)   6192        concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 10, 10, 32)   6304        conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 10, 10, 32)   6304        conv2d_31[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 10, 10, 128)  0           conv2d_23[0][0]
#                                                                  conv2d_24[0][0]
#                                                                  conv2d_27[0][0]
#                                                                  conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 10, 10, 32)   4128        concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 10, 10, 32)   7200        conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 10, 10, 24)   3096        concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 10, 10, 40)   9000        conv2d_36[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 128)    0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 4, 4, 24)     5208        conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 4, 4, 40)     14440       conv2d_37[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 4, 4, 192)    0           max_pooling2d_4[0][0]
#                                                                  conv2d_34[0][0]
#                                                                  conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 4, 4, 48)     9264        concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 4, 4, 56)     8120        conv2d_44[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 4, 4, 192)    0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 4, 4, 48)     9264        concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 4, 4, 64)     10816       conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 4, 4, 32)     6176        average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 4, 4, 32)     6176        concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 4, 4, 32)     4640        conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 4, 4, 32)     4640        conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 4, 4, 32)     6176        conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 4, 4, 32)     6176        conv2d_46[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 4, 4, 192)    0           conv2d_39[0][0]
#                                                                  conv2d_40[0][0]
#                                                                  conv2d_42[0][0]
#                                                                  conv2d_43[0][0]
#                                                                  conv2d_47[0][0]
#                                                                  conv2d_48[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 1, 1, 192)    0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1, 1, 192)    0           average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 192)          0           dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           1930        flatten_1[0][0]
# ==================================================================================================
# Total params: 213,334
# Trainable params: 213,334
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# %%time

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# Wall time: 189 ms

# %%
batch_size = 128
nb_epoch = 10
data_augmentation = False

# Model saving callback
#checkpointer = ModelCheckpoint(filepath='stochastic_depth_cifar10.hdf5', verbose=1, save_best_only=True)

if not data_augmentation:
    print('Not using data augmentation.')
    history = model.fit(x_train, y_train, 
                        batch_size=batch_size, nb_epoch=nb_epoch, verbose=1,
                        validation_data=(x_test, y_test), shuffle=True,
                        callbacks=[])
else:
    print('Using real-time data augmentation.')

    # realtime data augmentation
    datagen_train = ImageDataGenerator(
        featurewise_center=False,
        samplewise_center=False,
        featurewise_std_normalization=False,
        samplewise_std_normalization=False,
        zca_whitening=False,
        rotation_range=0,
        width_shift_range=0.125,
        height_shift_range=0.125,
        horizontal_flip=True,
        vertical_flip=False)
    datagen_train.fit(x_train)

    # fit the model on the batches generated by datagen.flow()
    history = model.fit_generator(datagen_train.flow(x_train, y_train, batch_size=batch_size, shuffle=True),
                                  samples_per_epoch=x_train.shape[0], 
                                  nb_epoch=nb_epoch, verbose=1,
                                  validation_data=(x_test, y_test),
                                  callbacks=[])
# Out:
# Not using data augmentation.
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# C:\Users\gmdhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   del sys.path[0]
# 50000/50000 [==============================] - 1546s 31ms/step - loss: 1.8979 - acc: 0.2750 - val_loss: 1.6264 - val_acc: 0.3975
# Epoch 2/10
# 50000/50000 [==============================] - 1511s 30ms/step - loss: 1.5609 - acc: 0.4296 - val_loss: 1.4598 - val_acc: 0.4737
# Epoch 3/10
# 22656/50000 [============>.................] - ETA: 14:32 - loss: 1.4127 - acc: 0.4905
