# %%
import pandas as pd
from pathlib import Path
import re

# %%
def read_in_cleaned_file(file_path):
    path=Path(file_path)
    input_doc = open(path, encoding = 'utf-8').read()
    
    return input_doc

# %%
pp_index = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-Index.txt')

# %%
pp_part_1 = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-I.txt')

# %%
pp_part_2= read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-II.txt')

# %%
pp_part_3 = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-III.txt')

# %%
pp_part_4_a_1 = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-IV-A-1.txt')

# %%
pp_part_4_a_2 = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-IV-A-2.txt')

# %%
pp_part_4_a_3 = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-IV-A-3.txt')

# %%
pp_part_4_a_4 = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-IV-A-4.txt')

# %%
pp_part_4_a_5 = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-IV-A-5.txt')

# %%
pp_part_4_b_1 = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-IV-B-1.txt')

# %%
pp_part_4_b_2 = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-IV-B-2.txt')

# %%
pp_part_4_b_3 = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-IV-B-3.txt')

# %%
pp_part_4_b_4 = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-IV-B-4.txt')

# %%
pp_part_4_b_5 = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-IV-B-5.txt')

# %%
pp_part_4_c_1 = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-IV-C-1.txt')

# %%
pp_part_4_c_2a = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-IV-C-2a.txt')

# %%
pp_part_4_c_2b = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-IV-C-2b.txt')

# %%
pp_part_4_c_2c = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-IV-C-2c.txt')

# %%
pp_part_4_c_3 = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-IV-C-3.txt')

# %%
pp_part_4_c_4 = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-IV-C-4.txt')

# %%
pp_part_4_c_5 = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-IV-C-5.txt')

# %%
pp_part_4_c_6_a = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-IV-C-6a.txt')

# %%
pp_part_4_c_6_b = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-IV-C-6b.txt')

# %%
pp_part_4_c_6_c = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-IV-C-6c.txt')

# %%
pp_part_4_c_7_a = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-IV-C-7a.txt')

# %%
pp_part_4_c_7_b = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-IV-C-7b.txt')

# %%
pp_part_4_c_8 = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-IV-C-8.txt')

# %%
pp_part_4_c_9a = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-IV-C-9a.txt')

# %%
pp_part_4_c_9b = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-IV-C-9b.txt')

# %%
pp_part_5_a_vol_ia = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-V-A-Vol-IA.txt')

# %%
pp_part_5_a_vol_ib = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-V-A-Vol-IB.txt')

# %%
pp_part_5_a_vol_ic = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-V-A-Vol-IC.txt')

# %%
pp_part_5_a_vol_iid = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-V-A-Vol-IID.txt')

# %%
pp_part_5_b_1 = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-V-B-1.txt')

# %%
pp_part_5_b_2a = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-V-B-2a.txt')

# %%
pp_part_5_b_2b = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-V-B-2b.txt')

# %%
pp_part_5_b_3a = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-V-B-3a.txt')

# %%
pp_part_5_b_3b = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-V-B-3b.txt')

# %%
pp_part_5_b_3c = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-V-B-3c.txt')

# %%
pp_part_5_b_3d = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-V-B-3d.txt')

# %%
pp_part_5_b_4_book_I = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-V-B-4-Book-I.txt')

# %%
pp_part_5_b_4_book_II  = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-V-B-4-Book-II.txt')

# %%
pp_part_6_a = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-VI-A.txt')

# %%
pp_part_6_b = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-VI-B.txt')

# %%
pp_part_6_c_1 = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-VI-C-1.txt')

# %%
pp_part_6_c_2 = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers-VI-C-2.txt')

# %%
pp_part_6_c_3 = read_in_cleaned_file('../../Cleaned_Pentagon_Papers_text_files/Cleaned_Pentagon-Papers
title_list = ["Index", "Vietnam and the U.S.", "U.S. Involvement in the Franco-Viet Minh War", "The Geneva Accords", "NATO and SEATO - A Comparison", "Aid for France in Indochina", "U.S. and France's Withdrawl from Vietnam", "U.S. Training of Vietnamese National Army", "Origins of the Insurgency", "The Kennedy Commitments and Programs", "Strategic Hamlet Program", "The Advisory Build-up", "Phased Withdrawl of U.S. Forces in Vietnam", "The Overthrow of Ngo Dinh Diem", "U.S. Programs in South Vietnam", "Military Pressures Against NVN - February-June 1964", "Military Pressures Against NVN - July-October 1964", "Military Pressures Against NVN - November-December 1964", "ROLLING THUNDER Program Begins",
            "Marine Combat Units Go to DaNang", "Phase I in the Build-Up of U.S. Forces", "U.S. Ground Strategy and Force Deployments - Volume I: Phase II, Phase 3, Phase 4", "U.S. Ground Strategy and Force Deployments - Volume II: Phase 5", "U.S. Ground Strategy and Force Deployments - Volume III: Program 6", "Air War in the North: Volume I", "Air War in the North: Volume II", "Re-emphasis on Pacification", "U.S.-GVN Relations - Volume 1", "U.S.-GVN Relations - Volume 2", "Public Statements - Volume I: A -- The Truman Administration", "Public Statements - Volume I: B -- The Eisenhower Administration", "Public Statements - Volume I: C -- The Kennedy Administration", "Public Statements - Volume II: D -- The Johnsom Administration","Internal Documents - The Roosevelt Administration", "Internal Documents - The Truman Administration: Volume I", "Internal Documents - The Truman Administration: Volume II", "Internal Documents - The Eisenhower Administration: Volume I", "Internal Documents - The Eisenhower Administration: Volume II", "Internal Documents - The Eisenhower Administration: Volume III", "Internal Documents - The Eisenhower Administration: Volume IV", "Internal Documents - The Kennedy Administration: Book I", "Internal Documents - The Kennedy Administration: Book II", "Negotiations: The Public Record", "Negotiations: Announced Public Statements", "Histories of Contacts - 1965-1966", "Histories of Contacts - Polish Track", "Histories of Contacts - Moscow-London Track", "Histories of Contacts - 1967-1968"]
print(len(title_list))

text_list = [pp_index, pp_part_1, pp_part_2, pp_part_3, pp_part_4_a_1, pp_part_4_a_2, pp_part_4_a_3, pp_part_4_a_4, pp_part_4_a_5, pp_part_4_b_1, pp_part_4_b_2, pp_part_4_b_3, pp_part_4_b_4, pp_part_4_b_5, pp_part_4_c_1, pp_part_4_c_2a, pp_part_4_c_2b, pp_part_4_c_2c, pp_part_4_c_3, pp_part_4_c_4, pp_part_4_c_5, pp_part_4_c_6_a, pp_part_4_c_6_b, pp_part_4_c_6_c, pp_part_4_c_7_a, pp_part_4_c_7_b, pp_part_4_c_8, pp_part_4_c_9a, pp_part_4_c_9b, pp_part_5_a_vol_ia, pp_part_5_a_vol_ib, pp_part_5_a_vol_ic, pp_part_5_a_vol_iid, pp_part_5_b_1, pp_part_5_b_2a, pp_part_5_b_2b, pp_part_5_b_3a, pp_part_5_b_3b, pp_part_5_b_3c, pp_part_5_b_3d, pp_part_5_b_4_book_I, pp_part_5_b_4_book_II, pp_part_6_a, pp_part_6_b, pp_part_6_c_1, pp_part_6_c_2, pp_part_6_c_3, pp_part_6_c_4]
    "text": [pp_index, pp_part_1, pp_part_2, pp_part_3, pp_part_4_a_1, pp_part_4_a_2, pp_part_4_a_3, pp_part_4_a_4, pp_part_4_a_5, pp_part_4_b_1, pp_part_4_b_2, pp_part_4_b_3, pp_part_4_b_4, pp_part_4_b_5, pp_part_4_c_1, pp_part_4_c_2a, pp_part_4_c_2b, pp_part_4_c_2c, pp_part_4_c_3, pp_part_4_c_4, pp_part_4_c_5, pp_part_4_c_6_a, pp_part_4_c_6_b, pp_part_4_c_6_c, pp_part_4_c_7_a, pp_part_4_c_7_b, pp_part_4_c_8, pp_part_4_c_9a, pp_part_4_c_9b, pp_part_5_a_vol_ia, pp_part_5_a_vol_ib, pp_part_5_a_vol_ic, pp_part_5_a_vol_iid, pp_part_5_b_1, pp_part_5_b_2a, pp_part_5_b_2b, pp_part_5_b_3a, pp_part_5_b_3b, pp_part_5_b_3c, pp_part_5_b_3d, pp_part_5_b_4_book_I, pp_part_5_b_4_book_II, pp_part_6_a, pp_part_6_b, pp_part_6_c_1, pp_part_6_c_2, pp_part_6_c_3, pp_part_6_c_4]})

# %%
main_df
# Out:
#                   name overall_years         specific_dates  \
# 0                Index     1945-1967              1945-1967
# 1               Part-I     1940-1950              1940-1950
# 2               Part-2     1950-1954              1950-1954
# 3               Part-3          1954                   1954
# 4          Part-IV-A-1     1954-1960              1954-1960
# 5          Part-IV-A-2     1950-1954              1950-1954
# 6          Part-IV-A-3     1954-1956              1954-1956
# 7          Part-IV-A-4     1954-1959              1954-1959
# 8          Part-IV-A-5     1954-1960              1954-1960
# 9          Part-IV-B-1          1961                   1961
# 10         Part-IV-B-2     1961-1963              1961-1963
# 11         Part-IV-B-3     1961-1967              1961-1967
# 12         Part-IV-B-4     1962-1964              1962-1964
# 13         Part-IV-B-5          1963        05/1963-11/1963
# 14         Part-IV-C-1     1963-1965        11/1963-04/1965
# ...

# %%
# concat dictionary to existing main dictionary OR merge on index
main_df = pd.concat([main_df, title_list], axis = 1)
# main_df

# %%
main_df = main_df[["name", 0, "overall_years", "specific_dates", "text"]]
# main_df

# %%
main_df.rename(columns = {0:'title'}, inplace = True)
main_df
# Out:
#                   name                                              title  \
# 0                Index                                              Index
# 1               Part-I                               Vietnam and the U.S.
# 2               Part-2       U.S. Involvement in the Franco-Viet Minh War
# 3               Part-3                                 The Geneva Accords
# 4          Part-IV-A-1                      NATO and SEATO - A Comparison
# 5          Part-IV-A-2                        Aid for France in Indochina
# 6          Part-IV-A-3           U.S. and France's Withdrawl from Vietnam
# 7          Part-IV-A-4          U.S. Training of Vietnamese National Army
# 8          Part-IV-A-5                          Origins of the Insurgency
# 9          Part-IV-B-1               The Kennedy Commitments and Programs
# 10         Part-IV-B-2                           Strategic Hamlet Program
# 11         Part-IV-B-3                              The Advisory Build-up
# ...

# %%
path = Path('../../Entity_Extraction/full_text_document.csv')
main_df.to_csv(r"C:\Users\bob\IS417_DSH\New_IS_417_DSH_V02\is417\Entity_Extraction\full_txt_document.csv")
# "C:\Users\bob\IS417_DSH\New_IS_417_DSH_V02\is417\Entity_Extraction"
