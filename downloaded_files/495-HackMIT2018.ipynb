# %%
from __future__ import print_function    # (at top of module)
import sys
import time

import json
import requests
from props.default import *

# %% [markdown]
# # Miscellaneous Functions

# %%
def log(m):
        print(m)
        
def setToken(t):
    global DL_TOKEN 
    DL_TOKEN = { 'Authorization' : 'DirectLogin token=%s' % t}
    
def mergeHeaders(x, y):
    z = x.copy()
    z.update(y)
    return z

def merge_headers_list(header_list):
    output_dict = {}
    for header in header_list:
        output_dict.update(header)
    return output_dict
        

CONTENT_JSON  = { 'content-type'  : 'application/json' }

# %% [markdown]
# # 1. Login in

# %%
def login(username, password, consumer_key):
    login_url = '{0}/my/logins/direct'.format(BASE_URL)
    login_header  = { 'Authorization' : 'DirectLogin username="%s",password="%s",consumer_key="%s"' % (username, password, consumer_key)}
    # Login and receive authorized token
    log('Login as {0} to {1}'.format(login_header, login_url))
    r = requests.post(login_url, headers=login_header)
    if (r.status_code != 201):
        log("error: could not login")
        log("text: " + r.text)
        return r.text
    t = r.json()['token']
    log("Received token: {0}".format(t))
    setToken(t)
    return t, login_header

# %%
login('wildunderrick', 'Spalding@11', 'ojfqqudfhvbfpuk3pzosjzf1dinjduzr4rfmbfja')
# Out:
# Login as {'Authorization': 'DirectLogin username="wildunderrick",password="Spalding@11",consumer_key="ojfqqudfhvbfpuk3pzosjzf1dinjduzr4rfmbfja"'} to https://bnpparibas-irb.openbankproject.com/my/logins/direct
# Received token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyIiOiIifQ.RXP_yRJqzgJnMMuLc_NhWvpypz-WJ8Al5rDiOuOYt-k
# ('eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyIiOiIifQ.RXP_yRJqzgJnMMuLc_NhWvpypz-WJ8Al5rDiOuOYt-k',
#  {'Authorization': 'DirectLogin username="wildunderrick",password="Spalding@11",consumer_key="ojfqqudfhvbfpuk3pzosjzf1dinjduzr4rfmbfja"'})

# %% [markdown]
# # 2. Data Warehouse

# %% [markdown]
# To have access to the datawarehouse you have to request the role on:
# https://bnpparibas-irb-explorer.openbankproject.com/#vv3_0_0-dataWarehouseSearch

# %% [markdown]
# Here is the list of index of the elastic search DB:
#
#
# irb-declared-products, irb-sme-transactions, irb-transactions, irb-contracts, irb-taxes, irb-charges, irb-revenues, irb-individual-clients, irb-markets, irb-sme-client, irb-assets, irb-sme-contracts
# bow-declared-products, bow-sme-transactions, bow-transactions, bow-contracts, bow-taxes, bow-charges, bow-revenues, bow-individual-clients, bow-markets, bow-sme-client, bow-assets, bow-sme-contracts
# 20170608-markets, 20170608-taxes, 20170608-charges

# %%
def request_datawarehouse_body(field, first_request_bool, last_index=None):
    post_data = {
        "size" : 10000,
        "query" : {"match_all":{}},
        "search_after" : [last_index],
        "sort" : [{"customer_id":"asc"}]
    }
    
    post_data_first_request = {
        "size" : 10000,
        "query" : {"match_all":{}},
        "sort" : [{"customer_id":"asc"}]
    }
    if first_request_bool:
        post_data=post_data_first_request
        
    response = requests.post(u"{0}/obp/{1}/search/warehouse/{2}".format(BASE_URL, API_VERSION, field), json=post_data, headers=mergeHeaders(DL_TOKEN, CONTENT_JSON))
    return response.json()

# %%
def request_datawarehouse(field, n):
    results = []
    first_request = True
    last_index = None
    
    while len(results) < n:
        print('iter')
        result = request_datawarehouse_body(field, first_request, last_index)
        first_request = False
        print(result['json'])
        last_index = result['json']['hits']['hits'][-1]['_source']['customer_id']
        results.extend(result['json']['hits']['hits'])
    return results

# %%
result = request_datawarehouse('irb-contracts', 1)
# Out:
# iter
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
result
# Out:
# [{'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '421699',
#   '_score': None,
#   '_source': {'product_category': 'LIFE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'HEALTH AND PENSION FUND CONTRACT',
#    'date_opened': '2012-02-07',
#    'customer_id': '1',
#    'balance_date': '2017-04-05',
#    'contract_id': '379154',
#    'product_id': '09ASPRES',
#    'product_supfamily': 'INSURANCE',
#    'product_name': 'ASSURCOMPTE'},
#   'sort': ['1']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '668771',
#   '_score': None,
#   '_source': {'product_category': 'OTHER RETIREMENT FUND CONTRACTS',
#    'balance': '0',
#    'product_family': 'PROTECTION ASSISTANCE',
#    'date_opened': '2006-01-05',
#    'customer_id': '1',
#    'balance_date': '2017-04-05',
#    'contract_id': '720971',
#    'product_id': '09SEC-PL',
#    'product_supfamily': 'INSURANCE',
#    'product_name': 'BNP SECURITY PLUS'},
#   'sort': ['1']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '514584',
#   '_score': None,
#   '_source': {'product_category': 'TELEMATIC ACCESS SERVICE',
#    'balance': '12514',
#    'product_family': 'ADDITIONAL PRODUCTS',
#    'date_opened': '2004-08-31',
#    'customer_id': '1',
#    'balance_date': '2017-04-06',
#    'contract_id': '721012',
#    'product_id': '01171',
#    'product_supfamily': 'TELEMATIC SERVICES',
#    'product_name': 'BOOK NOW SAVINGS'},
#   'sort': ['1']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '788950',
#   '_score': None,
#   '_source': {'product_category': 'WITHDRAWAL CARDS CONTRACTS',
#    'balance': '0',
#    'product_family': 'CARDS CONTRACTS',
#    'date_opened': '2012-02-08',
#    'customer_id': '1',
#    'balance_date': '2017-01-12',
#    'contract_id': '505083',
#    'product_id': '09000019',
#    'product_supfamily': 'SERVICES',
#    'product_name': 'CARD FIRST ONE'},
#   'sort': ['1']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '28924',
#   '_score': None,
#   '_source': {'product_category': 'CARDIF CONTRACTS',
#    'balance': '36262',
#    'product_family': 'LIFE INSURANCE',
#    'date_opened': '2012-02-07',
#    'customer_id': '1',
#    'balance_date': '2017-04-06',
#    'contract_id': '1080475',
#    'product_id': '01123',
#    'product_supfamily': 'SAVING',
#    'product_name': 'SAVINGS PLAN FLEXIVAL DANONE PEP'},
#   'sort': ['1']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '103291',
#   '_score': None,
#   '_source': {'product_category': 'ACCESS TO FUNDS SERVICE',
#    'balance': '2780',
#    'product_family': 'INTERNAL PRODUCT MANAGEMENT',
#    'date_opened': '2004-09-08',
#    'customer_id': '1',
#    'balance_date': '2017-04-06',
#    'contract_id': '306848',
#    'product_id': '01101',
#    'product_supfamily': 'OTHER SERVICES',
#    'product_name': 'CHECK ACCOUNT- CAV'},
#   'sort': ['1']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '448305',
#   '_score': None,
#   '_source': {'product_category': 'ACCESS BY CARD SERVICE',
#    'balance': '0',
#    'product_family': 'INTERNAL PRODUCT MANAGEMENT',
#    'date_opened': '2014-06-01',
#    'customer_id': '1',
#    'balance_date': '2017-04-05',
#    'contract_id': '504560',
#    'product_id': '09138018',
#    'product_supfamily': 'OTHER SERVICES',
#    'product_name': 'DEMATERIALIZATION CCHQ CEB PEA C'},
#   'sort': ['1']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '327661',
#   '_score': None,
#   '_source': {'product_category': 'FREE SPIRIT',
#    'balance': '0',
#    'product_family': 'MANAGEMENT SERVICES CONTRACTS',
#    'date_opened': '2004-09-08',
#    'customer_id': '1',
#    'balance_date': '2017-04-06',
#    'contract_id': '721354',
#    'product_id': '1200907',
#    'product_supfamily': 'SERVICES',
#    'product_name': 'FREE SPIRIT FIRST'},
#   'sort': ['1']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '894884',
#   '_score': None,
#   '_source': {'product_category': 'OTHER LIFE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'LIFE INSURANCE',
#    'date_opened': '2004-09-09',
#    'customer_id': '1',
#    'balance_date': '2014-12-31',
#    'contract_id': '721248',
#    'product_id': '030Q',
#    'product_supfamily': 'SAVING',
#    'product_name': 'TELEMATIQUE PART.SERVICES OFFER'},
#   'sort': ['1']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '253224',
#   '_score': None,
#   '_source': {'product_category': 'MORTGAGE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'DAMAGES CONTRACTS',
#    'date_opened': '2014-03-13',
#    'customer_id': '10',
#    'balance_date': '2017-04-04',
#    'contract_id': '389832',
#    'product_id': '09138418',
#    'product_supfamily': 'INSURANCE',
#    'product_name': 'HOUSE INSURANCE'},
#   'sort': ['10']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '890585',
#   '_score': None,
#   '_source': {'product_category': 'LIFE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'HEALTH AND PENSION FUND CONTRACT',
#    'date_opened': '2014-08-29',
#    'customer_id': '10',
#    'balance_date': '2017-04-05',
#    'contract_id': '426819',
#    'product_id': '09ASPRES',
#    'product_supfamily': 'INSURANCE',
#    'product_name': 'ASSURCOMPTE'},
#   'sort': ['10']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '1135228',
#   '_score': None,
#   '_source': {'product_category': 'FREE SPIRIT',
#    'balance': '0',
#    'product_family': 'MANAGEMENT SERVICES CONTRACTS',
#    'date_opened': '2012-07-24',
#    'customer_id': '10',
#    'balance_date': '2017-04-06',
#    'contract_id': '426753',
#    'product_id': '1200905',
#    'product_supfamily': 'SERVICES',
#    'product_name': 'VISA REGISTRATION OPEN MIND'},
#   'sort': ['10']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '411465',
#   '_score': None,
#   '_source': {'product_category': 'TELEMATIC ACCESS SERVICE',
#    'balance': '69',
#    'product_family': 'ADDITIONAL PRODUCTS',
#    'date_opened': '2012-07-24',
#    'customer_id': '10',
#    'balance_date': '2017-04-06',
#    'contract_id': '389540',
#    'product_id': '01174',
#    'product_supfamily': 'TELEMATIC SERVICES',
#    'product_name': 'A BOOKLET'},
#   'sort': ['10']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '522421',
#   '_score': None,
#   '_source': {'product_category': 'ACCESS BY CARD SERVICE',
#    'balance': '0',
#    'product_family': 'INTERNAL PRODUCT MANAGEMENT',
#    'date_opened': '2012-07-24',
#    'customer_id': '10',
#    'balance_date': '2017-04-05',
#    'contract_id': '389644',
#    'product_id': '09138018',
#    'product_supfamily': 'OTHER SERVICES',
#    'product_name': 'DEMATERIALIZATION CCHQ CEB PEA C'},
#   'sort': ['10']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '41808',
#   '_score': None,
#   '_source': {'product_category': 'LIFE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'HEALTH AND PENSION FUND CONTRACT',
#    'date_opened': '2012-07-24',
#    'customer_id': '10',
#    'balance_date': '2017-04-05',
#    'contract_id': '837400',
#    'product_id': '09SEC',
#    'product_supfamily': 'INSURANCE',
#    'product_name': 'BNP SECURITY'},
#   'sort': ['10']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '1096915',
#   '_score': None,
#   '_source': {'product_category': 'ACCESS TO FUNDS SERVICE',
#    'balance': '7378',
#    'product_family': 'INTERNAL PRODUCT MANAGEMENT',
#    'date_opened': '2012-07-24',
#    'customer_id': '10',
#    'balance_date': '2017-04-06',
#    'contract_id': '688531',
#    'product_id': '01101',
#    'product_supfamily': 'OTHER SERVICES',
#    'product_name': 'CHECK ACCOUNT- CAV'},
#   'sort': ['10']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '1141212',
#   '_score': None,
#   '_source': {'product_category': 'TELEMATIC ACCESS SERVICE',
#    'balance': '0',
#    'product_family': 'ADDITIONAL PRODUCTS',
#    'date_opened': '2012-07-24',
#    'customer_id': '10',
#    'balance_date': '2016-10-12',
#    'contract_id': '837346',
#    'product_id': '1260018',
#    'product_supfamily': 'TELEMATIC SERVICES',
#    'product_name': 'SITUATION'},
#   'sort': ['10']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '1007146',
#   '_score': None,
#   '_source': {'product_category': 'WITHDRAWAL CARDS CONTRACTS',
#    'balance': '0',
#    'product_family': 'CARDS CONTRACTS',
#    'date_opened': '2012-07-25',
#    'customer_id': '10',
#    'balance_date': '2015-08-14',
#    'contract_id': '389844',
#    'product_id': '09000012',
#    'product_supfamily': 'SERVICES',
#    'product_name': 'CARD VISA CLASSIC'},
#   'sort': ['10']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '625470',
#   '_score': None,
#   '_source': {'product_category': 'OTHER LIFE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'LIFE INSURANCE',
#    'date_opened': '2012-07-25',
#    'customer_id': '10',
#    'balance_date': '2014-12-31',
#    'contract_id': '837226',
#    'product_id': '030Q',
#    'product_supfamily': 'SAVING',
#    'product_name': 'TELEMATIQUE PART.SERVICES OFFER'},
#   'sort': ['10']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '574540',
#   '_score': None,
#   '_source': {'product_category': 'LIFE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'HEALTH AND PENSION FUND CONTRACT',
#    'date_opened': '2004-07-09',
#    'customer_id': '100',
#    'balance_date': '2015-01-15',
#    'contract_id': '41385',
#    'product_id': '01158',
#    'product_supfamily': 'INSURANCE',
#    'product_name': 'PROVISIO'},
#   'sort': ['100']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '1102046',
#   '_score': None,
#   '_source': {'product_category': 'TELEMATIC ACCESS SERVICE',
#    'balance': '513',
#    'product_family': 'ADDITIONAL PRODUCTS',
#    'date_opened': '1992-06-11',
#    'customer_id': '100',
#    'balance_date': '2017-04-06',
#    'contract_id': '589836',
#    'product_id': '01171',
#    'product_supfamily': 'TELEMATIC SERVICES',
#    'product_name': 'BOOK NOW SAVINGS'},
#   'sort': ['100']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '418244',
#   '_score': None,
#   '_source': {'product_category': 'FREE SPIRIT',
#    'balance': '0',
#    'product_family': 'MANAGEMENT SERVICES CONTRACTS',
#    'date_opened': '2001-11-22',
#    'customer_id': '100',
#    'balance_date': '2017-04-06',
#    'contract_id': '41243',
#    'product_id': '1200905',
#    'product_supfamily': 'SERVICES',
#    'product_name': 'VISA REGISTRATION OPEN MIND'},
#   'sort': ['100']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '669793',
#   '_score': None,
#   '_source': {'product_category': 'ACCESS TO FUNDS SERVICE',
#    'balance': '4310',
#    'product_family': 'INTERNAL PRODUCT MANAGEMENT',
#    'date_opened': '1984-07-12',
#    'customer_id': '100',
#    'balance_date': '2017-04-06',
#    'contract_id': '219129',
#    'product_id': '01101',
#    'product_supfamily': 'OTHER SERVICES',
#    'product_name': 'CHECK ACCOUNT- CAV'},
#   'sort': ['100']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '571565',
#   '_score': None,
#   '_source': {'product_category': 'WITHDRAWAL CARDS CONTRACTS',
#    'balance': '0',
#    'product_family': 'CARDS CONTRACTS',
#    'date_opened': '1991-06-01',
#    'customer_id': '100',
#    'balance_date': '2017-01-04',
#    'contract_id': '41678',
#    'product_id': '09000012',
#    'product_supfamily': 'SERVICES',
#    'product_name': 'CARD VISA CLASSIC'},
#   'sort': ['100']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '750048',
#   '_score': None,
#   '_source': {'product_category': 'OTHER LIFE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'LIFE INSURANCE',
#    'date_opened': '1992-06-12',
#    'customer_id': '100',
#    'balance_date': '2014-12-31',
#    'contract_id': '44253',
#    'product_id': '030Q',
#    'product_supfamily': 'SAVING',
#    'product_name': 'TELEMATIQUE PART.SERVICES OFFER'},
#   'sort': ['100']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '769960',
#   '_score': None,
#   '_source': {'product_category': 'OTHER RETIREMENT FUND CONTRACTS',
#    'balance': '0',
#    'product_family': 'PROTECTION ASSISTANCE',
#    'date_opened': '1992-05-20',
#    'customer_id': '100',
#    'balance_date': '2017-04-05',
#    'contract_id': '44242',
#    'product_id': '09SEC-PL',
#    'product_supfamily': 'INSURANCE',
#    'product_name': 'BNP SECURITY PLUS'},
#   'sort': ['100']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '713765',
#   '_score': None,
#   '_source': {'product_category': 'PAYMENT CARDS CONTRACTS',
#    'balance': '0',
#    'product_family': 'CARDS CONTRACTS',
#    'date_opened': '1992-06-11',
#    'customer_id': '100',
#    'balance_date': '2017-03-29',
#    'contract_id': '589434',
#    'product_id': '09CAS',
#    'product_supfamily': 'SERVICES',
#    'product_name': 'CASCADE'},
#   'sort': ['100']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '705898',
#   '_score': None,
#   '_source': {'product_category': 'OTHER BONDS / CAP CONTRACTS',
#    'balance': '0',
#    'product_family': 'LIFE INSURANCE',
#    'date_opened': '2015-09-08',
#    'customer_id': '100',
#    'balance_date': '2017-04-05',
#    'contract_id': '41593',
#    'product_id': '09139129',
#    'product_supfamily': 'SAVING',
#    'product_name': 'Nomadic insurance (ex MOBILEO 2)'},
#   'sort': ['100']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '677618',
#   '_score': None,
#   '_source': {'product_category': 'LIFE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'HEALTH AND PENSION FUND CONTRACT',
#    'date_opened': '2001-11-22',
#    'customer_id': '100',
#    'balance_date': '2017-04-05',
#    'contract_id': '41459',
#    'product_id': '09ASPRES',
#    'product_supfamily': 'INSURANCE',
#    'product_name': 'ASSURCOMPTE'},
#   'sort': ['100']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '1005171',
#   '_score': None,
#   '_source': {'product_category': 'PAYMENT CARDS CONTRACTS',
#    'balance': '0',
#    'product_family': 'CARDS CONTRACTS',
#    'date_opened': '2004-07-09',
#    'customer_id': '100',
#    'balance_date': '2015-08-12',
#    'contract_id': '41402',
#    'product_id': '09000886',
#    'product_supfamily': 'SERVICES',
#    'product_name': 'CARD PROVISIO MASTERCARD'},
#   'sort': ['100']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '678799',
#   '_score': None,
#   '_source': {'product_category': 'LOAN OFFICERS',
#    'balance': '-2554',
#    'product_family': 'MANAGERS LOAN',
#    'date_opened': '2011-11-28',
#    'customer_id': '1000',
#    'balance_date': '2017-04-06',
#    'contract_id': '225689',
#    'product_id': '11153P',
#    'product_supfamily': 'LOAN',
#    'product_name': 'PERSONAL LOAN'},
#   'sort': ['1000']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '394265',
#   '_score': None,
#   '_source': {'product_category': 'OTHER LIFE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'LIFE INSURANCE',
#    'date_opened': '2014-10-06',
#    'customer_id': '1000',
#    'balance_date': '2017-04-05',
#    'contract_id': '873568',
#    'product_id': '09000674',
#    'product_supfamily': 'SAVING',
#    'product_name': 'NEW OFFER INSURANCE / ADE'},
#   'sort': ['1000']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '999072',
#   '_score': None,
#   '_source': {'product_category': 'OTHER RETIREMENT FUND CONTRACTS',
#    'balance': '0',
#    'product_family': 'PROTECTION ASSISTANCE',
#    'date_opened': '1992-11-05',
#    'customer_id': '1000',
#    'balance_date': '2017-04-05',
#    'contract_id': '439296',
#    'product_id': '09SEC-PL',
#    'product_supfamily': 'INSURANCE',
#    'product_name': 'BNP SECURITY PLUS'},
#   'sort': ['1000']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '132605',
#   '_score': None,
#   '_source': {'product_category': 'WITHDRAWAL CARDS CONTRACTS',
#    'balance': '0',
#    'product_family': 'CARDS CONTRACTS',
#    'date_opened': '1998-07-17',
#    'customer_id': '1000',
#    'balance_date': '2015-08-12',
#    'contract_id': '438682',
#    'product_id': '09000012',
#    'product_supfamily': 'SERVICES',
#    'product_name': 'CARD VISA CLASSIC'},
#   'sort': ['1000']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '487082',
#   '_score': None,
#   '_source': {'product_category': 'OTHER LIFE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'LIFE INSURANCE',
#    'date_opened': '1992-11-13',
#    'customer_id': '1000',
#    'balance_date': '2014-12-31',
#    'contract_id': '225620',
#    'product_id': '030Q',
#    'product_supfamily': 'SAVING',
#    'product_name': 'TELEMATIQUE PART.SERVICES OFFER'},
#   'sort': ['1000']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '361872',
#   '_score': None,
#   '_source': {'product_category': 'LIFE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'HEALTH AND PENSION FUND CONTRACT',
#    'date_opened': '2001-05-25',
#    'customer_id': '1000',
#    'balance_date': '2017-04-05',
#    'contract_id': '225605',
#    'product_id': '09ASPRES',
#    'product_supfamily': 'INSURANCE',
#    'product_name': 'ASSURCOMPTE'},
#   'sort': ['1000']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '282835',
#   '_score': None,
#   '_source': {'product_category': 'LIFE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'HEALTH AND PENSION FUND CONTRACT',
#    'date_opened': '2001-03-05',
#    'customer_id': '1000',
#    'balance_date': '2017-04-05',
#    'contract_id': '297677',
#    'product_id': '09ASPRES',
#    'product_supfamily': 'INSURANCE',
#    'product_name': 'ASSURCOMPTE'},
#   'sort': ['1000']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '632363',
#   '_score': None,
#   '_source': {'product_category': 'FREE SPIRIT',
#    'balance': '0',
#    'product_family': 'MANAGEMENT SERVICES CONTRACTS',
#    'date_opened': '2001-03-05',
#    'customer_id': '1000',
#    'balance_date': '2017-04-06',
#    'contract_id': '439085',
#    'product_id': '1200905',
#    'product_supfamily': 'SERVICES',
#    'product_name': 'VISA REGISTRATION OPEN MIND'},
#   'sort': ['1000']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '861776',
#   '_score': None,
#   '_source': {'product_category': 'OTHER LIFE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'LIFE INSURANCE',
#    'date_opened': '2011-12-01',
#    'customer_id': '1000',
#    'balance_date': '2017-04-05',
#    'contract_id': '298234',
#    'product_id': '09000674',
#    'product_supfamily': 'SAVING',
#    'product_name': 'NEW OFFER INSURANCE / ADE'},
#   'sort': ['1000']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '939691',
#   '_score': None,
#   '_source': {'product_category': 'INVESTMENT CREDITS',
#    'balance': '-5192',
#    'product_family': 'CREDIT EQUIPMENT',
#    'date_opened': '2014-09-29',
#    'customer_id': '1000',
#    'balance_date': '2017-04-06',
#    'contract_id': '669568',
#    'product_id': '11153V',
#    'product_supfamily': 'LOAN',
#    'product_name': 'COMPATIBLE AUTO'},
#   'sort': ['1000']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '1013508',
#   '_score': None,
#   '_source': {'product_category': 'ACCESS TO FUNDS SERVICE',
#    'balance': '1746',
#    'product_family': 'INTERNAL PRODUCT MANAGEMENT',
#    'date_opened': '1992-11-05',
#    'customer_id': '1000',
#    'balance_date': '2017-04-06',
#    'contract_id': '298433',
#    'product_id': '01101',
#    'product_supfamily': 'OTHER SERVICES',
#    'product_name': 'CHECK ACCOUNT- CAV'},
#   'sort': ['1000']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '652159',
#   '_score': None,
#   '_source': {'product_category': 'OTHER LIFE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'LIFE INSURANCE',
#    'date_opened': '2013-03-11',
#    'customer_id': '10000',
#    'balance_date': '2014-12-31',
#    'contract_id': '168488',
#    'product_id': '030Q',
#    'product_supfamily': 'SAVING',
#    'product_name': 'TELEMATIQUE PART.SERVICES OFFER'},
#   'sort': ['10000']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '340104',
#   '_score': None,
#   '_source': {'product_category': 'ACCESS TO FUNDS SERVICE',
#    'balance': '11044',
#    'product_family': 'INTERNAL PRODUCT MANAGEMENT',
#    'date_opened': '2013-03-09',
#    'customer_id': '10000',
#    'balance_date': '2017-04-06',
#    'contract_id': '465482',
#    'product_id': '01101',
#    'product_supfamily': 'OTHER SERVICES',
#    'product_name': 'CHECK ACCOUNT- CAV'},
#   'sort': ['10000']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '393105',
#   '_score': None,
#   '_source': {'product_category': 'OTHER LIFE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'LIFE INSURANCE',
#    'date_opened': '2013-03-15',
#    'customer_id': '10000',
#    'balance_date': '2017-04-05',
#    'contract_id': '464942',
#    'product_id': '09000674',
#    'product_supfamily': 'SAVING',
#    'product_name': 'NEW OFFER INSURANCE / ADE'},
#   'sort': ['10000']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '554094',
#   '_score': None,
#   '_source': {'product_category': 'ACCESS BY CARD SERVICE',
#    'balance': '0',
#    'product_family': 'INTERNAL PRODUCT MANAGEMENT',
#    'date_opened': '2014-06-01',
#    'customer_id': '10000',
#    'balance_date': '2017-04-05',
#    'contract_id': '167912',
#    'product_id': '09138018',
#    'product_supfamily': 'OTHER SERVICES',
#    'product_name': 'DEMATERIALIZATION CCHQ CEB PEA C'},
#   'sort': ['10000']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '63314',
#   '_score': None,
#   '_source': {'product_category': 'INVESTMENT CREDITS',
#    'balance': '-78211',
#    'product_family': 'CREDIT EQUIPMENT',
#    'date_opened': '2013-03-15',
#    'customer_id': '10000',
#    'balance_date': '2017-04-06',
#    'contract_id': '186998',
#    'product_id': '111520',
#    'product_supfamily': 'LOAN',
#    'product_name': 'OTHER REAL-ESTATE LOAN'},
#   'sort': ['10000']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '487747',
#   '_score': None,
#   '_source': {'product_category': 'LIFE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'HEALTH AND PENSION FUND CONTRACT',
#    'date_opened': '2013-03-09',
#    'customer_id': '10000',
#    'balance_date': '2017-04-05',
#    'contract_id': '305132',
#    'product_id': '09SEC',
#    'product_supfamily': 'INSURANCE',
#    'product_name': 'BNP SECURITY'},
#   'sort': ['10000']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '551754',
#   '_score': None,
#   '_source': {'product_category': 'TELEMATIC ACCESS SERVICE',
#    'balance': '11300',
#    'product_family': 'ADDITIONAL PRODUCTS',
#    'date_opened': '2013-07-05',
#    'customer_id': '10000',
#    'balance_date': '2017-04-06',
#    'contract_id': '246153',
#    'product_id': '01174',
#    'product_supfamily': 'TELEMATIC SERVICES',
#    'product_name': 'A BOOKLET'},
#   'sort': ['10000']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '142642',
#   '_score': None,
#   '_source': {'product_category': 'MORTGAGE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'DAMAGES CONTRACTS',
#    'date_opened': '2011-05-11',
#    'customer_id': '100001',
#    'balance_date': '2017-04-04',
#    'contract_id': '497675',
#    'product_id': '09138418',
#    'product_supfamily': 'INSURANCE',
#    'product_name': 'HOUSE INSURANCE'},
#   'sort': ['100001']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '132221',
#   '_score': None,
#   '_source': {'product_category': 'TELEMATIC ACCESS SERVICE',
#    'balance': '18',
#    'product_family': 'ADDITIONAL PRODUCTS',
#    'date_opened': '2008-07-22',
#    'customer_id': '100001',
#    'balance_date': '2017-04-06',
#    'contract_id': '634407',
#    'product_id': '01171',
#    'product_supfamily': 'TELEMATIC SERVICES',
#    'product_name': 'BOOK NOW SAVINGS'},
#   'sort': ['100001']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '160010',
#   '_score': None,
#   '_source': {'product_category': 'LIFE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'HEALTH AND PENSION FUND CONTRACT',
#    'date_opened': '2008-06-25',
#    'customer_id': '100001',
#    'balance_date': '2017-04-05',
#    'contract_id': '273041',
#    'product_id': '09SEC',
#    'product_supfamily': 'INSURANCE',
#    'product_name': 'BNP SECURITY'},
#   'sort': ['100001']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '649615',
#   '_score': None,
#   '_source': {'product_category': 'REDEEMABLE CREDITS',
#    'balance': '0',
#    'product_family': 'PERSONAL LOANS',
#    'date_opened': '2016-08-25',
#    'customer_id': '100001',
#    'balance_date': '2017-04-05',
#    'contract_id': '343057',
#    'product_id': '09139277',
#    'product_supfamily': 'LOAN',
#    'product_name': 'MANUFACTURER WARRANTY EXTENSION'},
#   'sort': ['100001']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '983233',
#   '_score': None,
#   '_source': {'product_category': 'ACCESS BY CARD SERVICE',
#    'balance': '0',
#    'product_family': 'INTERNAL PRODUCT MANAGEMENT',
#    'date_opened': '2010-12-10',
#    'customer_id': '100001',
#    'balance_date': '2017-04-05',
#    'contract_id': '273060',
#    'product_id': '09138018',
#    'product_supfamily': 'OTHER SERVICES',
#    'product_name': 'DEMATERIALIZATION CCHQ CEB PEA C'},
#   'sort': ['100001']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '451070',
#   '_score': None,
#   '_source': {'product_category': 'OTHER LIFE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'LIFE INSURANCE',
#    'date_opened': '2008-06-26',
#    'customer_id': '100001',
#    'balance_date': '2014-12-31',
#    'contract_id': '273411',
#    'product_id': '030Q',
#    'product_supfamily': 'SAVING',
#    'product_name': 'TELEMATIQUE PART.SERVICES OFFER'},
#   'sort': ['100001']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '1055181',
#   '_score': None,
#   '_source': {'product_category': 'SAVINGS CONTRACTS',
#    'balance': '17',
#    'product_family': 'SAVINGS ACCOUNTS',
#    'date_opened': '2010-01-01',
#    'customer_id': '100001',
#    'balance_date': '2017-04-05',
#    'contract_id': '891948',
#    'product_id': '09101556',
#    'product_supfamily': 'SAVING',
#    'product_name': 'SAVINGS ACCOUNT Tx FIXE PP'},
#   'sort': ['100001']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '839586',
#   '_score': None,
#   '_source': {'product_category': 'TELEMATIC ACCESS SERVICE',
#    'balance': '0',
#    'product_family': 'ADDITIONAL PRODUCTS',
#    'date_opened': '2008-06-25',
#    'customer_id': '100001',
#    'balance_date': '2016-10-12',
#    'contract_id': '273125',
#    'product_id': '1260018',
#    'product_supfamily': 'TELEMATIC SERVICES',
#    'product_name': 'SITUATION'},
#   'sort': ['100001']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '251060',
#   '_score': None,
#   '_source': {'product_category': 'LEASE CONTRACTS',
#    'balance': '-8305',
#    'product_family': 'CREDIT EQUIPMENT',
#    'date_opened': '2012-08-01',
#    'customer_id': '100001',
#    'balance_date': '2017-04-06',
#    'contract_id': '273294',
#    'product_id': '1200218',
#    'product_supfamily': 'LOAN',
#    'product_name': 'CREDIT STUDENTS'},
#   'sort': ['100001']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '377908',
#   '_score': None,
#   '_source': {'product_category': 'ACCESS TO FUNDS SERVICE',
#    'balance': '9117',
#    'product_family': 'INTERNAL PRODUCT MANAGEMENT',
#    'date_opened': '2008-06-25',
#    'customer_id': '100001',
#    'balance_date': '2017-04-06',
#    'contract_id': '497505',
#    'product_id': '01101',
#    'product_supfamily': 'OTHER SERVICES',
#    'product_name': 'CHECK ACCOUNT- CAV'},
#   'sort': ['100001']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '13587',
#   '_score': None,
#   '_source': {'product_category': 'LIFE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'HEALTH AND PENSION FUND CONTRACT',
#    'date_opened': '2010-12-15',
#    'customer_id': '100001',
#    'balance_date': '2017-04-05',
#    'contract_id': '273544',
#    'product_id': '09ASPRES',
#    'product_supfamily': 'INSURANCE',
#    'product_name': 'ASSURCOMPTE'},
#   'sort': ['100001']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '148332',
#   '_score': None,
#   '_source': {'product_category': 'WITHDRAWAL CARDS CONTRACTS',
#    'balance': '0',
#    'product_family': 'CARDS CONTRACTS',
#    'date_opened': '2008-06-26',
#    'customer_id': '100001',
#    'balance_date': '2015-07-13',
#    'contract_id': '892747',
#    'product_id': '09000012',
#    'product_supfamily': 'SERVICES',
#    'product_name': 'CARD VISA CLASSIC'},
#   'sort': ['100001']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '456015',
#   '_score': None,
#   '_source': {'product_category': 'FREE SPIRIT',
#    'balance': '0',
#    'product_family': 'MANAGEMENT SERVICES CONTRACTS',
#    'date_opened': '2010-12-15',
#    'customer_id': '100001',
#    'balance_date': '2017-04-06',
#    'contract_id': '497108',
#    'product_id': '1200905',
#    'product_supfamily': 'SERVICES',
#    'product_name': 'VISA REGISTRATION OPEN MIND'},
#   'sort': ['100001']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '901245',
#   '_score': None,
#   '_source': {'product_category': 'OTHER LIFE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'LIFE INSURANCE',
#    'date_opened': '2012-08-07',
#    'customer_id': '100001',
#    'balance_date': '2017-04-05',
#    'contract_id': '273215',
#    'product_id': '09000674',
#    'product_supfamily': 'SAVING',
#    'product_name': 'NEW OFFER INSURANCE / ADE'},
#   'sort': ['100001']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '15968',
#   '_score': None,
#   '_source': {'product_category': 'ACCESS TO FUNDS SERVICE',
#    'balance': '5405',
#    'product_family': 'INTERNAL PRODUCT MANAGEMENT',
#    'date_opened': '1998-02-05',
#    'customer_id': '100002',
#    'balance_date': '2017-04-06',
#    'contract_id': '1070635',
#    'product_id': '01101',
#    'product_supfamily': 'OTHER SERVICES',
#    'product_name': 'CHECK ACCOUNT- CAV'},
#   'sort': ['100002']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '554157',
#   '_score': None,
#   '_source': {'product_category': 'TELEMATIC ACCESS SERVICE',
#    'balance': '1782',
#    'product_family': 'ADDITIONAL PRODUCTS',
#    'date_opened': '2000-06-15',
#    'customer_id': '100002',
#    'balance_date': '2017-04-06',
#    'contract_id': '1071026',
#    'product_id': '01171',
#    'product_supfamily': 'TELEMATIC SERVICES',
#    'product_name': 'BOOK NOW SAVINGS'},
#   'sort': ['100002']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '221432',
#   '_score': None,
#   '_source': {'product_category': 'WITHDRAWAL CARDS CONTRACTS',
#    'balance': '0',
#    'product_family': 'CARDS CONTRACTS',
#    'date_opened': '2009-05-15',
#    'customer_id': '100002',
#    'balance_date': '2016-07-20',
#    'contract_id': '112444',
#    'product_id': '09000012',
#    'product_supfamily': 'SERVICES',
#    'product_name': 'CARD VISA CLASSIC'},
#   'sort': ['100002']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '624153',
#   '_score': None,
#   '_source': {'product_category': 'MULTIINVESTMENT CONTRACTS',
#    'balance': '0',
#    'product_family': 'LIFE INSURANCE',
#    'date_opened': '2014-04-10',
#    'customer_id': '100002',
#    'balance_date': '2017-04-05',
#    'contract_id': '11449',
#    'product_id': '09000546',
#    'product_supfamily': 'SAVING',
#    'product_name': 'BNPP FAMILY protection'},
#   'sort': ['100002']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '772309',
#   '_score': None,
#   '_source': {'product_category': 'REDEEMABLE CREDITS',
#    'balance': '0',
#    'product_family': 'PERSONAL LOANS',
#    'date_opened': '2016-07-06',
#    'customer_id': '100002',
#    'balance_date': '2017-04-05',
#    'contract_id': '1070353',
#    'product_id': '09139277',
#    'product_supfamily': 'LOAN',
#    'product_name': 'MANUFACTURER WARRANTY EXTENSION'},
#   'sort': ['100002']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '920961',
#   '_score': None,
#   '_source': {'product_category': 'OTHER BONDS / CAP CONTRACTS',
#    'balance': '0',
#    'product_family': 'LIFE INSURANCE',
#    'date_opened': '2012-06-21',
#    'customer_id': '100002',
#    'balance_date': '2017-04-05',
#    'contract_id': '820256',
#    'product_id': '09139129',
#    'product_supfamily': 'SAVING',
#    'product_name': 'Nomadic insurance (ex MOBILEO 2)'},
#   'sort': ['100002']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '112693',
#   '_score': None,
#   '_source': {'product_category': 'LIFE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'HEALTH AND PENSION FUND CONTRACT',
#    'date_opened': '1998-02-05',
#    'customer_id': '100002',
#    'balance_date': '2017-04-05',
#    'contract_id': '820130',
#    'product_id': '09SEC',
#    'product_supfamily': 'INSURANCE',
#    'product_name': 'BNP SECURITY'},
#   'sort': ['100002']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '929383',
#   '_score': None,
#   '_source': {'product_category': 'FREE SPIRIT',
#    'balance': '0',
#    'product_family': 'MANAGEMENT SERVICES CONTRACTS',
#    'date_opened': '2003-12-05',
#    'customer_id': '100002',
#    'balance_date': '2017-04-06',
#    'contract_id': '11327',
#    'product_id': '1200905',
#    'product_supfamily': 'SERVICES',
#    'product_name': 'VISA REGISTRATION OPEN MIND'},
#   'sort': ['100002']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '355047',
#   '_score': None,
#   '_source': {'product_category': 'MORTGAGE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'DAMAGES CONTRACTS',
#    'date_opened': '2003-11-06',
#    'customer_id': '100002',
#    'balance_date': '2017-04-05',
#    'contract_id': '820590',
#    'product_id': '09100285',
#    'product_supfamily': 'INSURANCE',
#    'product_name': 'HOUSE INSURANCE (OLD)'},
#   'sort': ['100002']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '746495',
#   '_score': None,
#   '_source': {'product_category': 'LIFE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'HEALTH AND PENSION FUND CONTRACT',
#    'date_opened': '2003-12-05',
#    'customer_id': '100002',
#    'balance_date': '2017-04-05',
#    'contract_id': '11493',
#    'product_id': '09ASPRES',
#    'product_supfamily': 'INSURANCE',
#    'product_name': 'ASSURCOMPTE'},
#   'sort': ['100002']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '593743',
#   '_score': None,
#   '_source': {'product_category': 'OTHER LIFE INSURANCE CONTRACTS',
#    'balance': '2138',
#    'product_family': 'LIFE INSURANCE',
#    'date_opened': '2007-03-21',
#    'customer_id': '100002',
#    'balance_date': '2017-04-05',
#    'contract_id': '11573',
#    'product_id': '09000350',
#    'product_supfamily': 'SAVING',
#    'product_name': 'BNP PARIBAS multiinvestments 2'},
#   'sort': ['100002']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '984366',
#   '_score': None,
#   '_source': {'product_category': 'OTHER LIFE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'LIFE INSURANCE',
#    'date_opened': '1998-02-06',
#    'customer_id': '100002',
#    'balance_date': '2017-03-13',
#    'contract_id': '11346',
#    'product_id': '030Q',
#    'product_supfamily': 'SAVING',
#    'product_name': 'TELEMATIQUE PART.SERVICES OFFER'},
#   'sort': ['100002']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '852217',
#   '_score': None,
#   '_source': {'product_category': 'REDEEMABLE CREDITS',
#    'balance': '0',
#    'product_family': 'PERSONAL LOANS',
#    'date_opened': '2013-08-27',
#    'customer_id': '100002',
#    'balance_date': '2017-04-05',
#    'contract_id': '11258',
#    'product_id': '09139277',
#    'product_supfamily': 'LOAN',
#    'product_name': 'MANUFACTURER WARRANTY EXTENSION'},
#   'sort': ['100002']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '227334',
#   '_score': None,
#   '_source': {'product_category': 'OTHER LIFE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'LIFE INSURANCE',
#    'date_opened': '2009-09-25',
#    'customer_id': '100004',
#    'balance_date': '2017-04-05',
#    'contract_id': '825039',
#    'product_id': '09000674',
#    'product_supfamily': 'SAVING',
#    'product_name': 'NEW OFFER INSURANCE / ADE'},
#   'sort': ['100004']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '500192',
#   '_score': None,
#   '_source': {'product_category': 'INVESTMENT CREDITS',
#    'balance': '-4713',
#    'product_family': 'CREDIT EQUIPMENT',
#    'date_opened': '2009-09-16',
#    'customer_id': '100004',
#    'balance_date': '2017-04-06',
#    'contract_id': '978187',
#    'product_id': '11153V',
#    'product_supfamily': 'LOAN',
#    'product_name': 'COMPATIBLE AUTO'},
#   'sort': ['100004']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '666321',
#   '_score': None,
#   '_source': {'product_category': 'OTHER LIFE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'LIFE INSURANCE',
#    'date_opened': '2006-12-01',
#    'customer_id': '100004',
#    'balance_date': '2014-12-31',
#    'contract_id': '978060',
#    'product_id': '030Q',
#    'product_supfamily': 'SAVING',
#    'product_name': 'TELEMATIQUE PART.SERVICES OFFER'},
#   'sort': ['100004']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '851660',
#   '_score': None,
#   '_source': {'product_category': 'ACCESS TO FUNDS SERVICE',
#    'balance': '8124',
#    'product_family': 'INTERNAL PRODUCT MANAGEMENT',
#    'date_opened': '2006-11-30',
#    'customer_id': '100004',
#    'balance_date': '2017-04-06',
#    'contract_id': '373914',
#    'product_id': '01101',
#    'product_supfamily': 'OTHER SERVICES',
#    'product_name': 'CHECK ACCOUNT- CAV'},
#   'sort': ['100004']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '213479',
#   '_score': None,
#   '_source': {'product_category': 'REDEEMABLE CREDITS',
#    'balance': '0',
#    'product_family': 'PERSONAL LOANS',
#    'date_opened': '2014-01-09',
#    'customer_id': '100004',
#    'balance_date': '2017-04-05',
#    'contract_id': '825029',
#    'product_id': '09139277',
#    'product_supfamily': 'LOAN',
#    'product_name': 'MANUFACTURER WARRANTY EXTENSION'},
#   'sort': ['100004']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '1151459',
#   '_score': None,
#   '_source': {'product_category': 'ACCESS BY CARD SERVICE',
#    'balance': '0',
#    'product_family': 'INTERNAL PRODUCT MANAGEMENT',
#    'date_opened': '2009-08-23',
#    'customer_id': '100004',
#    'balance_date': '2017-04-05',
#    'contract_id': '978130',
#    'product_id': '09138018',
#    'product_supfamily': 'OTHER SERVICES',
#    'product_name': 'DEMATERIALIZATION CCHQ CEB PEA C'},
#   'sort': ['100004']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '1140168',
#   '_score': None,
#   '_source': {'product_category': 'REDEEMABLE CREDITS',
#    'balance': '0',
#    'product_family': 'PERSONAL LOANS',
#    'date_opened': '2016-12-06',
#    'customer_id': '100004',
#    'balance_date': '2017-04-05',
#    'contract_id': '978279',
#    'product_id': '09139277',
#    'product_supfamily': 'LOAN',
#    'product_name': 'MANUFACTURER WARRANTY EXTENSION'},
#   'sort': ['100004']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '58620',
#   '_score': None,
#   '_source': {'product_category': 'PAYMENT CARDS CONTRACTS',
#    'balance': '0',
#    'product_family': 'CARDS CONTRACTS',
#    'date_opened': '2009-09-10',
#    'customer_id': '100004',
#    'balance_date': '2015-10-13',
#    'contract_id': '373495',
#    'product_id': '09000886',
#    'product_supfamily': 'SERVICES',
#    'product_name': 'CARD PROVISIO MASTERCARD'},
#   'sort': ['100004']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '157522',
#   '_score': None,
#   '_source': {'product_category': 'LIFE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'HEALTH AND PENSION FUND CONTRACT',
#    'date_opened': '2009-09-10',
#    'customer_id': '100004',
#    'balance_date': '2015-01-15',
#    'contract_id': '373661',
#    'product_id': '01158',
#    'product_supfamily': 'INSURANCE',
#    'product_name': 'PROVISIO'},
#   'sort': ['100004']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '474219',
#   '_score': None,
#   '_source': {'product_category': 'REDEEMABLE CREDITS',
#    'balance': '0',
#    'product_family': 'PERSONAL LOANS',
#    'date_opened': '2013-04-20',
#    'customer_id': '100004',
#    'balance_date': '2017-04-05',
#    'contract_id': '506569',
#    'product_id': '09139277',
#    'product_supfamily': 'LOAN',
#    'product_name': 'MANUFACTURER WARRANTY EXTENSION'},
#   'sort': ['100004']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '900126',
#   '_score': None,
#   '_source': {'product_category': 'OTHER LIFE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'LIFE INSURANCE',
#    'date_opened': '2014-09-19',
#    'customer_id': '100004',
#    'balance_date': '2017-04-05',
#    'contract_id': '506334',
#    'product_id': '09000674',
#    'product_supfamily': 'SAVING',
#    'product_name': 'NEW OFFER INSURANCE / ADE'},
#   'sort': ['100004']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '954644',
#   '_score': None,
#   '_source': {'product_category': 'WITHDRAWAL CARDS CONTRACTS',
#    'balance': '0',
#    'product_family': 'CARDS CONTRACTS',
#    'date_opened': '2008-04-21',
#    'customer_id': '100004',
#    'balance_date': '2016-12-08',
#    'contract_id': '332503',
#    'product_id': '09000012',
#    'product_supfamily': 'SERVICES',
#    'product_name': 'CARD VISA CLASSIC'},
#   'sort': ['100004']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '923278',
#   '_score': None,
#   '_source': {'product_category': 'LOAN OFFICERS',
#    'balance': '-10393',
#    'product_family': 'MANAGERS LOAN',
#    'date_opened': '2014-09-10',
#    'customer_id': '100004',
#    'balance_date': '2017-04-06',
#    'contract_id': '373457',
#    'product_id': '11153P',
#    'product_supfamily': 'LOAN',
#    'product_name': 'PERSONAL LOAN'},
#   'sort': ['100004']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '86923',
#   '_score': None,
#   '_source': {'product_category': 'TELEMATIC ACCESS SERVICE',
#    'balance': '6498',
#    'product_family': 'ADDITIONAL PRODUCTS',
#    'date_opened': '2009-01-09',
#    'customer_id': '100005',
#    'balance_date': '2017-04-06',
#    'contract_id': '55274',
#    'product_id': '01174',
#    'product_supfamily': 'TELEMATIC SERVICES',
#    'product_name': 'A BOOKLET'},
#   'sort': ['100005']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '267988',
#   '_score': None,
#   '_source': {'product_category': 'ACCESS TO FUNDS SERVICE',
#    'balance': '-561',
#    'product_family': 'INTERNAL PRODUCT MANAGEMENT',
#    'date_opened': '1984-11-27',
#    'customer_id': '100005',
#    'balance_date': '2017-04-06',
#    'contract_id': '58034',
#    'product_id': '01101',
#    'product_supfamily': 'OTHER SERVICES',
#    'product_name': 'CHECK ACCOUNT- CAV'},
#   'sort': ['100005']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '309226',
#   '_score': None,
#   '_source': {'product_category': 'MORTGAGE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'DAMAGES CONTRACTS',
#    'date_opened': '1994-12-05',
#    'customer_id': '100005',
#    'balance_date': '2017-04-05',
#    'contract_id': '36539',
#    'product_id': '09100285',
#    'product_supfamily': 'INSURANCE',
#    'product_name': 'HOUSE INSURANCE (OLD)'},
#   'sort': ['100005']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '340721',
#   '_score': None,
#   '_source': {'product_category': 'LIFE INSURANCE CONTRACTS',
#    'balance': '-4494',
#    'product_family': 'HEALTH AND PENSION FUND CONTRACT',
#    'date_opened': '2000-03-07',
#    'customer_id': '100005',
#    'balance_date': '2015-01-15',
#    'contract_id': '48247',
#    'product_id': '01158',
#    'product_supfamily': 'INSURANCE',
#    'product_name': 'PROVISIO'},
#   'sort': ['100005']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '526778',
#   '_score': None,
#   '_source': {'product_category': 'FREE SPIRIT',
#    'balance': '0',
#    'product_family': 'MANAGEMENT SERVICES CONTRACTS',
#    'date_opened': '2000-12-08',
#    'customer_id': '100005',
#    'balance_date': '2017-04-06',
#    'contract_id': '57441',
#    'product_id': '1200907',
#    'product_supfamily': 'SERVICES',
#    'product_name': 'FREE SPIRIT FIRST'},
#   'sort': ['100005']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '914182',
#   '_score': None,
#   '_source': {'product_category': 'OTHER LIFE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'LIFE INSURANCE',
#    'date_opened': '2001-11-19',
#    'customer_id': '100005',
#    'balance_date': '2014-12-31',
#    'contract_id': '48245',
#    'product_id': '030Q',
#    'product_supfamily': 'SAVING',
#    'product_name': 'TELEMATIQUE PART.SERVICES OFFER'},
#   'sort': ['100005']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '888316',
#   '_score': None,
#   '_source': {'product_category': 'OTHER RETIREMENT FUND CONTRACTS',
#    'balance': '0',
#    'product_family': 'PROTECTION ASSISTANCE',
#    'date_opened': '2000-12-08',
#    'customer_id': '100005',
#    'balance_date': '2017-04-05',
#    'contract_id': '54811',
#    'product_id': '09SEC-PL',
#    'product_supfamily': 'INSURANCE',
#    'product_name': 'BNP SECURITY PLUS'},
#   'sort': ['100005']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '871057',
#   '_score': None,
#   '_source': {'product_category': 'TELEMATIC ACCESS SERVICE',
#    'balance': '353',
#    'product_family': 'ADDITIONAL PRODUCTS',
#    'date_opened': '2004-08-31',
#    'customer_id': '100005',
#    'balance_date': '2017-04-06',
#    'contract_id': '49093',
#    'product_id': '01171',
#    'product_supfamily': 'TELEMATIC SERVICES',
#    'product_name': 'BOOK NOW SAVINGS'},
#   'sort': ['100005']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '356825',
#   '_score': None,
#   '_source': {'product_category': 'PAYMENT CARDS CONTRACTS',
#    'balance': '0',
#    'product_family': 'CARDS CONTRACTS',
#    'date_opened': '1998-07-22',
#    'customer_id': '100005',
#    'balance_date': '2015-08-12',
#    'contract_id': '55117',
#    'product_id': '09000886',
#    'product_supfamily': 'SERVICES',
#    'product_name': 'CARD PROVISIO MASTERCARD'},
#   'sort': ['100005']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '660430',
#   '_score': None,
#   '_source': {'product_category': 'LIFE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'HEALTH AND PENSION FUND CONTRACT',
#    'date_opened': '2000-12-08',
#    'customer_id': '100005',
#    'balance_date': '2017-04-05',
#    'contract_id': '55181',
#    'product_id': '09ASPRES',
#    'product_supfamily': 'INSURANCE',
#    'product_name': 'ASSURCOMPTE'},
#   'sort': ['100005']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '1059571',
#   '_score': None,
#   '_source': {'product_category': 'ACCESS BY CARD SERVICE',
#    'balance': '0',
#    'product_family': 'INTERNAL PRODUCT MANAGEMENT',
#    'date_opened': '2014-06-01',
#    'customer_id': '100005',
#    'balance_date': '2017-04-05',
#    'contract_id': '36397',
#    'product_id': '09138018',
#    'product_supfamily': 'OTHER SERVICES',
#    'product_name': 'DEMATERIALIZATION CCHQ CEB PEA C'},
#   'sort': ['100005']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '469452',
#   '_score': None,
#   '_source': {'product_category': 'LIFE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'HEALTH AND PENSION FUND CONTRACT',
#    'date_opened': '2000-12-09',
#    'customer_id': '100007',
#    'balance_date': '2017-04-05',
#    'contract_id': '456180',
#    'product_id': '09SEC',
#    'product_supfamily': 'INSURANCE',
#    'product_name': 'BNP SECURITY'},
#   'sort': ['100007']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '766795',
#   '_score': None,
#   '_source': {'product_category': 'TELEMATIC ACCESS SERVICE',
#    'balance': '11826',
#    'product_family': 'ADDITIONAL PRODUCTS',
#    'date_opened': '1992-06-24',
#    'customer_id': '100007',
#    'balance_date': '2017-04-06',
#    'contract_id': '209412',
#    'product_id': '01171',
#    'product_supfamily': 'TELEMATIC SERVICES',
#    'product_name': 'BOOK NOW SAVINGS'},
#   'sort': ['100007']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '820547',
#   '_score': None,
#   '_source': {'product_category': 'WITHDRAWAL CARDS CONTRACTS',
#    'balance': '0',
#    'product_family': 'CARDS CONTRACTS',
#    'date_opened': '1991-10-01',
#    'customer_id': '100007',
#    'balance_date': '2016-10-07',
#    'contract_id': '174004',
#    'product_id': '09000012',
#    'product_supfamily': 'SERVICES',
#    'product_name': 'CARD VISA CLASSIC'},
#   'sort': ['100007']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '233144',
#   '_score': None,
#   '_source': {'product_category': 'PAYMENT CARDS CONTRACTS',
#    'balance': '0',
#    'product_family': 'CARDS CONTRACTS',
#    'date_opened': '1992-06-24',
#    'customer_id': '100007',
#    'balance_date': '2017-03-29',
#    'contract_id': '209423',
#    'product_id': '09CAS',
#    'product_supfamily': 'SERVICES',
#    'product_name': 'CASCADE'},
#   'sort': ['100007']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '320337',
# ...
#    'product_id': '09139277',
#    'product_supfamily': 'LOAN',
#    'product_name': 'MANUFACTURER WARRANTY EXTENSION'},
#   'sort': ['100117']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '667129',
#   '_score': None,
#   '_source': {'product_category': 'ACCESS TO FUNDS SERVICE',
#    'balance': '-403',
#    'product_family': 'INTERNAL PRODUCT MANAGEMENT',
#    'date_opened': '1972-11-06',
#    'customer_id': '100117',
#    'balance_date': '2017-04-06',
#    'contract_id': '823946',
#    'product_id': '01101',
#    'product_supfamily': 'OTHER SERVICES',
#    'product_name': 'CHECK ACCOUNT- CAV'},
#   'sort': ['100117']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '620328',
#   '_score': None,
#   '_source': {'product_category': 'ACCESS TO FUNDS SERVICE',
#    'balance': '-2044',
#    'product_family': 'INTERNAL PRODUCT MANAGEMENT',
#    'date_opened': '1998-09-21',
#    'customer_id': '100117',
#    'balance_date': '2017-04-06',
#    'contract_id': '501631',
#    'product_id': '01101',
#    'product_supfamily': 'OTHER SERVICES',
#    'product_name': 'CHECK ACCOUNT- CAV'},
#   'sort': ['100117']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '773233',
#   '_score': None,
#   '_source': {'product_category': 'OTHER RETIREMENT FUND CONTRACTS',
#    'balance': '0',
#    'product_family': 'PROTECTION ASSISTANCE',
#    'date_opened': '1990-03-30',
#    'customer_id': '100117',
#    'balance_date': '2014-12-31',
#    'contract_id': '769823',
#    'product_id': '09138011',
#    'product_supfamily': 'INSURANCE',
#    'product_name': 'ASSURPEP'},
#   'sort': ['100117']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '6458',
#   '_score': None,
#   '_source': {'product_category': 'OTHER RETIREMENT FUND CONTRACTS',
#    'balance': '0',
#    'product_family': 'PROTECTION ASSISTANCE',
#    'date_opened': '2001-05-29',
#    'customer_id': '100117',
#    'balance_date': '2017-04-05',
#    'contract_id': '824118',
#    'product_id': '09SEC-PL',
#    'product_supfamily': 'INSURANCE',
#    'product_name': 'BNP SECURITY PLUS'},
#   'sort': ['100117']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '402389',
#   '_score': None,
#   '_source': {'product_category': 'TELEMATIC ACCESS SERVICE',
#    'balance': '0',
#    'product_family': 'ADDITIONAL PRODUCTS',
#    'date_opened': '2013-10-31',
#    'customer_id': '100117',
#    'balance_date': '2015-01-14',
#    'contract_id': '770172',
#    'product_id': '09001099',
#    'product_supfamily': 'TELEMATIC SERVICES',
#    'product_name': 'PERSONAL SERVICES'},
#   'sort': ['100117']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '475962',
#   '_score': None,
#   '_source': {'product_category': 'OTHER LIFE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'LIFE INSURANCE',
#    'date_opened': '1994-06-02',
#    'customer_id': '100117',
#    'balance_date': '2014-12-31',
#    'contract_id': '989572',
#    'product_id': '030Q',
#    'product_supfamily': 'SAVING',
#    'product_name': 'TELEMATIQUE PART.SERVICES OFFER'},
#   'sort': ['100117']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '90477',
#   '_score': None,
#   '_source': {'product_category': 'OTHER SECURITIES CONTRACTS',
#    'balance': '0',
#    'product_family': 'SECURITIES ACCOUNT',
#    'date_opened': '1995-11-21',
#    'customer_id': '100117',
#    'balance_date': '2017-03-07',
#    'contract_id': '824230',
#    'product_id': '126000O',
#    'product_supfamily': 'SAVING',
#    'product_name': 'PANORAMA'},
#   'sort': ['100117']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '422362',
#   '_score': None,
#   '_source': {'product_category': 'WITHDRAWAL CARDS CONTRACTS',
#    'balance': '0',
#    'product_family': 'CARDS CONTRACTS',
#    'date_opened': '2008-07-16',
#    'customer_id': '100117',
#    'balance_date': '2015-08-12',
#    'contract_id': '770024',
#    'product_id': '09000019',
#    'product_supfamily': 'SERVICES',
#    'product_name': 'CARD FIRST ONE'},
#   'sort': ['100117']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '673967',
#   '_score': None,
#   '_source': {'product_category': 'WITHDRAWAL CARDS CONTRACTS',
#    'balance': '0',
#    'product_family': 'CARDS CONTRACTS',
#    'date_opened': '2013-11-04',
#    'customer_id': '100117',
#    'balance_date': '2016-10-07',
#    'contract_id': '1125289',
#    'product_id': '09000012',
#    'product_supfamily': 'SERVICES',
#    'product_name': 'CARD VISA CLASSIC'},
#   'sort': ['100117']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '728921',
#   '_score': None,
#   '_source': {'product_category': 'LIFE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'HEALTH AND PENSION FUND CONTRACT',
#    'date_opened': '2008-07-15',
#    'customer_id': '100117',
#    'balance_date': '2017-04-05',
#    'contract_id': '770131',
#    'product_id': '09ASPRES',
#    'product_supfamily': 'INSURANCE',
#    'product_name': 'ASSURCOMPTE'},
#   'sort': ['100117']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '63921',
#   '_score': None,
#   '_source': {'product_category': 'FREE SPIRIT',
#    'balance': '0',
#    'product_family': 'MANAGEMENT SERVICES CONTRACTS',
#    'date_opened': '2008-07-15',
#    'customer_id': '100117',
#    'balance_date': '2017-04-06',
#    'contract_id': '989131',
#    'product_id': '1200905',
#    'product_supfamily': 'SERVICES',
#    'product_name': 'VISA REGISTRATION OPEN MIND'},
#   'sort': ['100117']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '270287',
#   '_score': None,
#   '_source': {'product_category': 'TELEMATIC ACCESS SERVICE',
#    'balance': '586',
#    'product_family': 'ADDITIONAL PRODUCTS',
#    'date_opened': '1983-10-03',
#    'customer_id': '100117',
#    'balance_date': '2017-04-06',
#    'contract_id': '824105',
#    'product_id': '01171',
#    'product_supfamily': 'TELEMATIC SERVICES',
#    'product_name': 'BOOK NOW SAVINGS'},
#   'sort': ['100117']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '642522',
#   '_score': None,
#   '_source': {'product_category': 'WITHDRAWAL CARDS CONTRACTS',
#    'balance': '0',
#    'product_family': 'CARDS CONTRACTS',
#    'date_opened': '2004-10-29',
#    'customer_id': '100117',
#    'balance_date': '2015-11-12',
#    'contract_id': '988860',
#    'product_id': '09000032',
#    'product_supfamily': 'SERVICES',
#    'product_name': 'CARD GOLD BUSINESS'},
#   'sort': ['100117']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '676851',
#   '_score': None,
#   '_source': {'product_category': 'REDEEMABLE CREDITS',
#    'balance': '0',
#    'product_family': 'PERSONAL LOANS',
#    'date_opened': '2013-04-20',
#    'customer_id': '100117',
#    'balance_date': '2017-04-05',
#    'contract_id': '1125169',
#    'product_id': '09139277',
#    'product_supfamily': 'LOAN',
#    'product_name': 'MANUFACTURER WARRANTY EXTENSION'},
#   'sort': ['100117']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '86571',
#   '_score': None,
#   '_source': {'product_category': 'WITHDRAWAL CARDS CONTRACTS',
#    'balance': '0',
#    'product_family': 'CARDS CONTRACTS',
#    'date_opened': '2004-09-23',
#    'customer_id': '100119',
#    'balance_date': '2015-10-13',
#    'contract_id': '238525',
#    'product_id': '09000019',
#    'product_supfamily': 'SERVICES',
#    'product_name': 'CARD FIRST ONE'},
#   'sort': ['100119']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '873429',
#   '_score': None,
#   '_source': {'product_category': 'MORTGAGE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'DAMAGES CONTRACTS',
#    'date_opened': '1999-12-13',
#    'customer_id': '100119',
#    'balance_date': '2017-04-05',
#    'contract_id': '712700',
#    'product_id': '09100285',
#    'product_supfamily': 'INSURANCE',
#    'product_name': 'HOUSE INSURANCE (OLD)'},
#   'sort': ['100119']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '742319',
#   '_score': None,
#   '_source': {'product_category': 'TELEMATIC ACCESS SERVICE',
#    'balance': '0',
#    'product_family': 'ADDITIONAL PRODUCTS',
#    'date_opened': '2005-02-23',
#    'customer_id': '100119',
#    'balance_date': '2017-04-05',
#    'contract_id': '457785',
#    'product_id': '09000394',
#    'product_supfamily': 'TELEMATIC SERVICES',
#    'product_name': 'BNP ACCIDENT COVERAGE'},
#   'sort': ['100119']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '272847',
#   '_score': None,
#   '_source': {'product_category': 'REDEEMABLE CREDITS',
#    'balance': '0',
#    'product_family': 'PERSONAL LOANS',
#    'date_opened': '2014-03-24',
#    'customer_id': '100119',
#    'balance_date': '2015-01-09',
#    'contract_id': '152504',
#    'product_id': '09139277',
#    'product_supfamily': 'LOAN',
#    'product_name': 'MANUFACTURER WARRANTY EXTENSION'},
#   'sort': ['100119']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '537363',
#   '_score': None,
#   '_source': {'product_category': 'OTHER LIFE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'LIFE INSURANCE',
#    'date_opened': '1998-07-10',
#    'customer_id': '100119',
#    'balance_date': '2014-12-31',
#    'contract_id': '152295',
#    'product_id': '030Q',
#    'product_supfamily': 'SAVING',
#    'product_name': 'TELEMATIQUE PART.SERVICES OFFER'},
#   'sort': ['100119']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '885846',
#   '_score': None,
#   '_source': {'product_category': 'OTHER LIFE INSURANCE CONTRACTS',
#    'balance': '40622',
#    'product_family': 'LIFE INSURANCE',
#    'date_opened': '2005-02-23',
#    'customer_id': '100119',
#    'balance_date': '2017-04-05',
#    'contract_id': '458112',
#    'product_id': '09000350',
#    'product_supfamily': 'SAVING',
#    'product_name': 'BNP PARIBAS multiinvestments 2'},
#   'sort': ['100119']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '1070544',
#   '_score': None,
#   '_source': {'product_category': 'FREE SPIRIT',
#    'balance': '0',
#    'product_family': 'MANAGEMENT SERVICES CONTRACTS',
#    'date_opened': '2004-09-22',
#    'customer_id': '100119',
#    'balance_date': '2017-04-06',
#    'contract_id': '712194',
#    'product_id': '1200907',
#    'product_supfamily': 'SERVICES',
#    'product_name': 'FREE SPIRIT FIRST'},
#   'sort': ['100119']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '67400',
#   '_score': None,
#   '_source': {'product_category': 'PAYMENT CARDS CONTRACTS',
#    'balance': '0',
#    'product_family': 'CARDS CONTRACTS',
#    'date_opened': '2008-09-17',
#    'customer_id': '100119',
#    'balance_date': '2015-10-13',
#    'contract_id': '457479',
#    'product_id': '09000030',
#    'product_supfamily': 'SERVICES',
#    'product_name': 'CARD CIRRUS'},
#   'sort': ['100119']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '651554',
#   '_score': None,
#   '_source': {'product_category': 'TELEMATIC ACCESS SERVICE',
#    'balance': '16',
#    'product_family': 'ADDITIONAL PRODUCTS',
#    'date_opened': '2005-02-23',
#    'customer_id': '100119',
#    'balance_date': '2017-04-06',
#    'contract_id': '151995',
#    'product_id': '01189',
#    'product_supfamily': 'TELEMATIC SERVICES',
#    'product_name': 'P.E.A.'},
#   'sort': ['100119']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '800762',
#   '_score': None,
#   '_source': {'product_category': 'REDEEMABLE CREDITS',
#    'balance': '0',
#    'product_family': 'PERSONAL LOANS',
#    'date_opened': '2014-02-28',
#    'customer_id': '100119',
#    'balance_date': '2015-01-09',
#    'contract_id': '418804',
#    'product_id': '09139277',
#    'product_supfamily': 'LOAN',
#    'product_name': 'MANUFACTURER WARRANTY EXTENSION'},
#   'sort': ['100119']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '875888',
#   '_score': None,
#   '_source': {'product_category': 'OTHER RETIREMENT FUND CONTRACTS',
#    'balance': '0',
#    'product_family': 'PROTECTION ASSISTANCE',
#    'date_opened': '1998-07-01',
#    'customer_id': '100119',
#    'balance_date': '2017-04-05',
#    'contract_id': '712232',
#    'product_id': '09SEC-PL',
#    'product_supfamily': 'INSURANCE',
#    'product_name': 'BNP SECURITY PLUS'},
#   'sort': ['100119']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '149484',
#   '_score': None,
#   '_source': {'product_category': 'HORIZONS CONTRACTS',
#    'balance': '70',
#    'product_family': 'LIFE INSURANCE',
#    'date_opened': '2004-07-28',
#    'customer_id': '100119',
#    'balance_date': '2017-04-05',
#    'contract_id': '238151',
#    'product_id': '09000669',
#    'product_supfamily': 'SAVING',
#    'product_name': 'HOUSING SAVINGS PLAN'},
#   'sort': ['100119']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '195114',
#   '_score': None,
#   '_source': {'product_category': 'TELEMATIC ACCESS SERVICE',
#    'balance': '0',
#    'product_family': 'ADDITIONAL PRODUCTS',
#    'date_opened': '1998-07-09',
#    'customer_id': '100119',
#    'balance_date': '2016-10-12',
#    'contract_id': '712338',
#    'product_id': '1260018',
#    'product_supfamily': 'TELEMATIC SERVICES',
#    'product_name': 'SITUATION'},
#   'sort': ['100119']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '224037',
#   '_score': None,
#   '_source': {'product_category': 'LIFE INSURANCE CONTRACTS',
#    'balance': '0',
#    'product_family': 'HEALTH AND PENSION FUND CONTRACT',
#    'date_opened': '2004-09-22',
#    'customer_id': '100119',
#    'balance_date': '2017-04-05',
#    'contract_id': '419034',
#    'product_id': '09ASPRES',
#    'product_supfamily': 'INSURANCE',
#    'product_name': 'ASSURCOMPTE'},
#   'sort': ['100119']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '325744',
#   '_score': None,
#   '_source': {'product_category': 'CURRENT ACCOUNT CONTRACT',
#    'balance': '46',
#    'product_family': 'CURRENT ACCOUNTS',
#    'date_opened': '2005-10-28',
#    'customer_id': '100119',
#    'balance_date': '2017-04-05',
#    'contract_id': '418662',
#    'product_id': '01181',
#    'product_supfamily': 'SAVING',
#    'product_name': 'ACCOUNT FINANCIAL INSTRUMENTS'},
#   'sort': ['100119']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '612334',
#   '_score': None,
#   '_source': {'product_category': 'REDEEMABLE CREDITS',
#    'balance': '0',
#    'product_family': 'PERSONAL LOANS',
#    'date_opened': '2014-01-30',
#    'customer_id': '100119',
#    'balance_date': '2017-04-05',
#    'contract_id': '457742',
#    'product_id': '09139277',
#    'product_supfamily': 'LOAN',
#    'product_name': 'MANUFACTURER WARRANTY EXTENSION'},
#   'sort': ['100119']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '711333',
#   '_score': None,
#   '_source': {'product_category': 'ACCESS TO FUNDS SERVICE',
#    'balance': '4198',
#    'product_family': 'INTERNAL PRODUCT MANAGEMENT',
#    'date_opened': '1998-07-08',
#    'customer_id': '100119',
#    'balance_date': '2017-04-06',
#    'contract_id': '712530',
#    'product_id': '01101',
#    'product_supfamily': 'OTHER SERVICES',
#    'product_name': 'CHECK ACCOUNT- CAV'},
#   'sort': ['100119']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '862490',
#   '_score': None,
#   '_source': {'product_category': 'MULTIINVESTMENT CONTRACTS',
#    'balance': '0',
#    'product_family': 'LIFE INSURANCE',
#    'date_opened': '2006-01-13',
#    'customer_id': '100119',
#    'balance_date': '2017-04-05',
#    'contract_id': '457625',
#    'product_id': '09000546',
#    'product_supfamily': 'SAVING',
#    'product_name': 'BNPP FAMILY protection'},
#   'sort': ['100119']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '67413',
#   '_score': None,
#   '_source': {'product_category': 'MULTIINVESTMENT CONTRACTS',
#    'balance': '0',
#    'product_family': 'LIFE INSURANCE',
#    'date_opened': '2007-06-26',
#    'customer_id': '10012',
#    'balance_date': '2017-04-05',
#    'contract_id': '249787',
#    'product_id': '09000546',
#    'product_supfamily': 'SAVING',
#    'product_name': 'BNPP FAMILY protection'},
#   'sort': ['10012']},
#  {'_index': 'irb-contracts',
#   '_type': 'default',
#   '_id': '59325',
#   '_score': None,
#   '_source': {'product_category': 'TELEMATIC ACCESS SERVICE',
#    'balance': '2000',
#    'product_family': 'ADDITIONAL PRODUCTS',
#    'date_opened': '2015-03-06',
#    'customer_id': '10012',
#    'balance_date': '2017-04-04',
#    'contract_id': '878912',
#    'product_id': '1200067',
#    'product_supfamily': 'TELEMATIC SERVICES',
#    'product_name': 'OVERDRAFT FACILITY'},
#   'sort': ['10012']},
#  ...]

# %%
def request_datawarehouse_agg():
    post_data = {
         "size" : 20,
        "aggs": {
            "byindex": {
                  "terms": {
                    "field": "_index"
                  }
                }
        },
        "query"   : {"match_all":{          }  },
    }
    # Send post request with attached json
    response = requests.post(u"{0}/obp/{1}/search/warehouse/{2}".format(BASE_URL, API_VERSION, 'ALL'), json=post_data, headers=mergeHeaders(DL_TOKEN, CONTENT_JSON))
    return response.json()
