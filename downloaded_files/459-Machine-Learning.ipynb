# %%
import pandas as pd

data = pd.read_csv(r'E:\Python\Dataset.csv')
data.head()
data.shape
# Out:
# (569, 33)

# %%
#Scatter Plot
data.plot.scatter(x='radius_mean', y='texture_mean', title='Dataset')

# %%
#Line Chart
data.drop(['radius_mean'], axis=1).plot.line(title='Dataset')

# %%
#Histogram
data['radius_mean'].plot.hist()

# %%
#Bar chart
x['radius_mean'].value_counts().sort_index().plot.bar()

# %%
#Horizontal Bar chart
x['radius_mean'].value_counts().sort_index().plot.barh()
